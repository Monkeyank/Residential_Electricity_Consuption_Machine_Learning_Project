# %%
import csv
import random
import math
import operator
from sklearn.metrics import mean_squared_error

# Loading Data Set
def load_Dataset(filename, split, trainingSet=[] , testSet=[]):
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
        for x in range(len(dataset)-1):
            for y in range(24):
                dataset[x][y] = float(dataset[x][y])
            if random.random() < split:
                trainingSet.append(dataset[x])
            else:
                testSet.append(dataset[x])

# Euclidean distance algorithm for training set + test instance
# length controls the which fields to include in distance calculation

def euclidean_Distance(instance1, instance2, length):
    distance = 0
    for x in range(length):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)

# Finding the neighbors of the test instance in the training set

def get_Neighbors(trainingSet, testInstance, k):
    distances = []
    length = len(testInstance)-1
    for x in range(len(trainingSet)):
        dist = euclidean_Distance(testInstance, trainingSet[x], length)
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors
 
# Voting on all the neighbors to classify the test instance 

def get_Response(neighbors):
    Votes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][-1]
        if response in Votes:
            Votes[response] += 1
        else:
            Votes[response] = 1
    sortedVotes = sorted(Votes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]
 
# Accuracy test

def get_Accuracy(testSet, predictions):
    correct = 0
    for x in range(len(testSet)):
        if (testSet[x][-1] <predictions[x]*1.15 and testSet[x][-1] >predictions[x]*0.85) :
            correct += 1
    return (correct/float(len(testSet))) * 100.0

def main():
    # Format Date
    trainingSet=[]
    testSet=[]
    split = 0.95
    load_Dataset('finalinputs.csv', split, trainingSet, testSet)
    print ('Train set: ' + repr(len(trainingSet)))
    print ('Test set: ' + repr(len(testSet)) + '\n') 
    # generate predictions
    predictions=[]
    k = 9
    for x in range(len(testSet)):
        neighbors = get_Neighbors(trainingSet, testSet[x], k)
        result = get_Response(neighbors)
        predictions.append(result)
        print('> Predicted = $' + repr(result) + ', Actual = $' + repr(testSet[x][-1]))
        #print('> Actual = ' + repr(testSet[x][-1]) + ', Predicted = ' + repr(result))
    accuracy = get_Accuracy(testSet, predictions)
    print('Accuracy: ' + repr(accuracy))
main()
# Out:
# Train set: 10864
# Test set: 1218
#
# > Predicted = $664.0, Actual = $475.0
# > Predicted = $510.0, Actual = $551.0
# > Predicted = $350.0, Actual = $337.0
# > Predicted = $665.0, Actual = $922.0
# > Predicted = $2512.0, Actual = $2595.0
# > Predicted = $1364.0, Actual = $1096.0
# > Predicted = $1276.0, Actual = $1663.0
# > Predicted = $1719.0, Actual = $2467.0
# > Predicted = $1845.0, Actual = $2046.0
# > Predicted = $1803.0, Actual = $3077.0
# > Predicted = $477.0, Actual = $374.0
# > Predicted = $917.0, Actual = $1342.0
# > Predicted = $677.0, Actual = $755.0
# > Predicted = $599.0, Actual = $954.0
# > Predicted = $470.0, Actual = $502.0
# > Predicted = $507.0, Actual = $837.0
# > Predicted = $2254.0, Actual = $2298.0
# > Predicted = $911.0, Actual = $807.0
# > Predicted = $229.0, Actual = $392.0
# > Predicted = $1338.0, Actual = $1790.0
# > Predicted = $724.0, Actual = $758.0
# > Predicted = $749.0, Actual = $524.0
# > Predicted = $880.0, Actual = $609.0
# > Predicted = $823.0, Actual = $625.0
# > Predicted = $788.0, Actual = $657.0
# > Predicted = $404.0, Actual = $601.0
# > Predicted = $1116.0, Actual = $1126.0
# > Predicted = $871.0, Actual = $1168.0
# > Predicted = $668.0, Actual = $675.0
# > Predicted = $995.0, Actual = $964.0
# > Predicted = $1547.0, Actual = $1212.0
# > Predicted = $354.0, Actual = $385.0
# > Predicted = $1177.0, Actual = $993.0
# > Predicted = $2095.0, Actual = $1551.0
# > Predicted = $1674.0, Actual = $1518.0
# > Predicted = $3355.0, Actual = $2895.0
# > Predicted = $3058.0, Actual = $1931.0
# > Predicted = $5361.0, Actual = $3986.0
# > Predicted = $190.0, Actual = $255.0
# > Predicted = $897.0, Actual = $934.0
# > Predicted = $2431.0, Actual = $2092.0
# > Predicted = $2209.0, Actual = $3543.0
# > Predicted = $755.0, Actual = $1319.0
# > Predicted = $902.0, Actual = $1298.0
# > Predicted = $1042.0, Actual = $990.0
# > Predicted = $458.0, Actual = $540.0
# > Predicted = $799.0, Actual = $845.0
# > Predicted = $952.0, Actual = $978.0
# > Predicted = $800.0, Actual = $414.0
# > Predicted = $2897.0, Actual = $2901.0
# > Predicted = $2009.0, Actual = $1822.0
# > Predicted = $899.0, Actual = $1415.0
# > Predicted = $1192.0, Actual = $905.0
# > Predicted = $1522.0, Actual = $1310.0
# > Predicted = $1748.0, Actual = $2001.0
# > Predicted = $1366.0, Actual = $1003.0
# > Predicted = $1289.0, Actual = $666.0
# > Predicted = $1122.0, Actual = $1115.0
# > Predicted = $1666.0, Actual = $1686.0
# > Predicted = $1778.0, Actual = $2248.0
# > Predicted = $1971.0, Actual = $1698.0
# > Predicted = $1169.0, Actual = $970.0
# > Predicted = $2783.0, Actual = $2768.0
# > Predicted = $1547.0, Actual = $1603.0
# > Predicted = $1550.0, Actual = $1589.0
# > Predicted = $722.0, Actual = $700.0
# > Predicted = $750.0, Actual = $720.0
# > Predicted = $678.0, Actual = $731.0
# > Predicted = $462.0, Actual = $446.0
# > Predicted = $645.0, Actual = $580.0
# > Predicted = $1243.0, Actual = $1240.0
# > Predicted = $717.0, Actual = $472.0
# > Predicted = $2008.0, Actual = $1329.0
# > Predicted = $3355.0, Actual = $3831.0
# > Predicted = $3643.0, Actual = $5801.0
# > Predicted = $1437.0, Actual = $1021.0
# > Predicted = $883.0, Actual = $1030.0
# > Predicted = $2001.0, Actual = $2049.0
# > Predicted = $1011.0, Actual = $1110.0
# > Predicted = $927.0, Actual = $814.0
# > Predicted = $387.0, Actual = $453.0
# > Predicted = $2629.0, Actual = $2057.0
# > Predicted = $1129.0, Actual = $1575.0
# > Predicted = $669.0, Actual = $413.0
# > Predicted = $697.0, Actual = $378.0
# > Predicted = $520.0, Actual = $605.0
# > Predicted = $903.0, Actual = $1036.0
# > Predicted = $2194.0, Actual = $2230.0
# > Predicted = $1055.0, Actual = $941.0
# > Predicted = $2467.0, Actual = $1638.0
# > Predicted = $1722.0, Actual = $1573.0
# > Predicted = $1772.0, Actual = $1995.0
# > Predicted = $1291.0, Actual = $1118.0
# > Predicted = $984.0, Actual = $1016.0
# > Predicted = $2087.0, Actual = $2060.0
# > Predicted = $1698.0, Actual = $1740.0
# > Predicted = $735.0, Actual = $534.0
# > Predicted = $1513.0, Actual = $1354.0
# > Predicted = $682.0, Actual = $476.0
# > Predicted = $859.0, Actual = $671.0
# > Predicted = $1755.0, Actual = $1796.0
# > Predicted = $1759.0, Actual = $1376.0
# > Predicted = $1628.0, Actual = $1513.0
# > Predicted = $1691.0, Actual = $1932.0
# > Predicted = $1625.0, Actual = $1188.0
# > Predicted = $1224.0, Actual = $1191.0
# > Predicted = $1127.0, Actual = $1066.0
# > Predicted = $3848.0, Actual = $3554.0
# > Predicted = $2919.0, Actual = $2783.0
# > Predicted = $1223.0, Actual = $1207.0
# > Predicted = $506.0, Actual = $536.0
# > Predicted = $1899.0, Actual = $3288.0
# > Predicted = $482.0, Actual = $429.0
# > Predicted = $609.0, Actual = $626.0
# > Predicted = $888.0, Actual = $851.0
# > Predicted = $445.0, Actual = $380.0
# > Predicted = $923.0, Actual = $1016.0
# > Predicted = $969.0, Actual = $786.0
# > Predicted = $619.0, Actual = $457.0
# > Predicted = $2720.0, Actual = $2149.0
# > Predicted = $787.0, Actual = $695.0
# > Predicted = $1244.0, Actual = $1004.0
# > Predicted = $276.0, Actual = $576.0
# > Predicted = $1915.0, Actual = $1898.0
# > Predicted = $106.0, Actual = $245.0
# > Predicted = $1345.0, Actual = $1352.0
# > Predicted = $558.0, Actual = $514.0
# > Predicted = $909.0, Actual = $654.0
# > Predicted = $1231.0, Actual = $1756.0
# > Predicted = $1952.0, Actual = $1925.0
# > Predicted = $1485.0, Actual = $1374.0
# > Predicted = $1889.0, Actual = $925.0
# > Predicted = $430.0, Actual = $559.0
# > Predicted = $3017.0, Actual = $4830.0
# > Predicted = $2522.0, Actual = $2498.0
# > Predicted = $870.0, Actual = $895.0
# > Predicted = $584.0, Actual = $435.0
# > Predicted = $2432.0, Actual = $3420.0
# > Predicted = $401.0, Actual = $316.0
# > Predicted = $3084.0, Actual = $2818.0
# > Predicted = $609.0, Actual = $739.0
# > Predicted = $1740.0, Actual = $1774.0
# > Predicted = $1432.0, Actual = $1439.0
# > Predicted = $1009.0, Actual = $749.0
# > Predicted = $2462.0, Actual = $3058.0
# > Predicted = $1871.0, Actual = $1719.0
# > Predicted = $1051.0, Actual = $968.0
# > Predicted = $1216.0, Actual = $1611.0
# > Predicted = $1760.0, Actual = $1567.0
# > Predicted = $367.0, Actual = $354.0
# > Predicted = $2487.0, Actual = $4105.0
# > Predicted = $2546.0, Actual = $2237.0
# > Predicted = $377.0, Actual = $399.0
# > Predicted = $3903.0, Actual = $2688.0
# > Predicted = $858.0, Actual = $1144.0
# > Predicted = $1998.0, Actual = $2089.0
# > Predicted = $1364.0, Actual = $1447.0
# > Predicted = $1216.0, Actual = $1173.0
# > Predicted = $1371.0, Actual = $1676.0
# > Predicted = $1453.0, Actual = $1417.0
# > Predicted = $1423.0, Actual = $1324.0
# > Predicted = $199.0, Actual = $300.0
# > Predicted = $1337.0, Actual = $1130.0
# > Predicted = $1899.0, Actual = $1800.0
# > Predicted = $100.0, Actual = $79.0
# > Predicted = $538.0, Actual = $541.0
# > Predicted = $1191.0, Actual = $817.0
# > Predicted = $1454.0, Actual = $1422.0
# > Predicted = $923.0, Actual = $1813.0
# > Predicted = $829.0, Actual = $915.0
# > Predicted = $2737.0, Actual = $3051.0
# > Predicted = $496.0, Actual = $371.0
# > Predicted = $554.0, Actual = $532.0
# > Predicted = $1075.0, Actual = $927.0
# > Predicted = $1860.0, Actual = $2023.0
# > Predicted = $1068.0, Actual = $1104.0
# > Predicted = $361.0, Actual = $341.0
# > Predicted = $2793.0, Actual = $1813.0
# > Predicted = $2024.0, Actual = $1910.0
# > Predicted = $1662.0, Actual = $1725.0
# > Predicted = $703.0, Actual = $873.0
# > Predicted = $3471.0, Actual = $3263.0
# > Predicted = $773.0, Actual = $1008.0
# > Predicted = $1779.0, Actual = $1939.0
# > Predicted = $471.0, Actual = $797.0
# > Predicted = $861.0, Actual = $1319.0
# > Predicted = $3369.0, Actual = $4559.0
# > Predicted = $1141.0, Actual = $1365.0
# > Predicted = $284.0, Actual = $212.0
# > Predicted = $2723.0, Actual = $1929.0
# > Predicted = $967.0, Actual = $1089.0
# > Predicted = $473.0, Actual = $605.0
# > Predicted = $854.0, Actual = $736.0
# > Predicted = $743.0, Actual = $711.0
# > Predicted = $2042.0, Actual = $1817.0
# > Predicted = $1630.0, Actual = $1603.0
# > Predicted = $6777.0, Actual = $4189.0
# > Predicted = $338.0, Actual = $119.0
# > Predicted = $1723.0, Actual = $1049.0
# > Predicted = $1589.0, Actual = $1647.0
# > Predicted = $1254.0, Actual = $995.0
# > Predicted = $867.0, Actual = $1199.0
# > Predicted = $1024.0, Actual = $849.0
# > Predicted = $979.0, Actual = $945.0
# > Predicted = $1267.0, Actual = $1281.0
# > Predicted = $662.0, Actual = $719.0
# > Predicted = $1002.0, Actual = $1028.0
# > Predicted = $526.0, Actual = $571.0
# > Predicted = $254.0, Actual = $202.0
# > Predicted = $2696.0, Actual = $3117.0
# > Predicted = $2105.0, Actual = $2049.0
# > Predicted = $622.0, Actual = $613.0
# > Predicted = $2134.0, Actual = $1796.0
# > Predicted = $2893.0, Actual = $2917.0
# > Predicted = $669.0, Actual = $287.0
# > Predicted = $1825.0, Actual = $3454.0
# > Predicted = $1822.0, Actual = $1895.0
# > Predicted = $2256.0, Actual = $1939.0
# > Predicted = $193.0, Actual = $233.0
# > Predicted = $1274.0, Actual = $958.0
# > Predicted = $762.0, Actual = $933.0
# > Predicted = $2011.0, Actual = $1788.0
# > Predicted = $4224.0, Actual = $3237.0
# > Predicted = $832.0, Actual = $483.0
# > Predicted = $1352.0, Actual = $872.0
# > Predicted = $1412.0, Actual = $1598.0
# > Predicted = $2190.0, Actual = $2034.0
# > Predicted = $360.0, Actual = $576.0
# > Predicted = $700.0, Actual = $559.0
# > Predicted = $899.0, Actual = $1082.0
# > Predicted = $1548.0, Actual = $1582.0
# > Predicted = $993.0, Actual = $1563.0
# > Predicted = $979.0, Actual = $1071.0
# > Predicted = $100.0, Actual = $58.0
# > Predicted = $1473.0, Actual = $703.0
# > Predicted = $8012.0, Actual = $11409.0
# > Predicted = $2548.0, Actual = $2090.0
# > Predicted = $1329.0, Actual = $1020.0
# > Predicted = $1191.0, Actual = $1236.0
# > Predicted = $1502.0, Actual = $1786.0
# > Predicted = $2652.0, Actual = $3238.0
# > Predicted = $353.0, Actual = $467.0
# > Predicted = $2869.0, Actual = $1663.0
# > Predicted = $519.0, Actual = $460.0
# > Predicted = $1026.0, Actual = $585.0
# > Predicted = $1012.0, Actual = $1029.0
# > Predicted = $1953.0, Actual = $2370.0
# > Predicted = $1007.0, Actual = $1166.0
# > Predicted = $1143.0, Actual = $1185.0
# > Predicted = $789.0, Actual = $591.0
# > Predicted = $1041.0, Actual = $688.0
# > Predicted = $1334.0, Actual = $1365.0
# > Predicted = $812.0, Actual = $851.0
# > Predicted = $1288.0, Actual = $1598.0
# > Predicted = $2599.0, Actual = $1985.0
# > Predicted = $2613.0, Actual = $2962.0
# > Predicted = $708.0, Actual = $446.0
# > Predicted = $1183.0, Actual = $1651.0
# > Predicted = $628.0, Actual = $746.0
# > Predicted = $2323.0, Actual = $2257.0
# > Predicted = $1452.0, Actual = $1777.0
# > Predicted = $310.0, Actual = $434.0
# > Predicted = $1785.0, Actual = $2043.0
# > Predicted = $833.0, Actual = $649.0
# > Predicted = $686.0, Actual = $1229.0
# > Predicted = $939.0, Actual = $1662.0
# > Predicted = $474.0, Actual = $499.0
# > Predicted = $1119.0, Actual = $915.0
# > Predicted = $1581.0, Actual = $1903.0
# > Predicted = $1129.0, Actual = $1084.0
# > Predicted = $623.0, Actual = $1240.0
# > Predicted = $1176.0, Actual = $1282.0
# > Predicted = $620.0, Actual = $507.0
# > Predicted = $1305.0, Actual = $1494.0
# > Predicted = $704.0, Actual = $726.0
# > Predicted = $860.0, Actual = $712.0
# > Predicted = $901.0, Actual = $1580.0
# > Predicted = $1091.0, Actual = $1380.0
# > Predicted = $259.0, Actual = $222.0
# > Predicted = $494.0, Actual = $948.0
# > Predicted = $1515.0, Actual = $1769.0
# > Predicted = $574.0, Actual = $790.0
# > Predicted = $1779.0, Actual = $1394.0
# > Predicted = $4783.0, Actual = $4171.0
# > Predicted = $877.0, Actual = $996.0
# > Predicted = $1206.0, Actual = $1297.0
# > Predicted = $1246.0, Actual = $1396.0
# > Predicted = $677.0, Actual = $867.0
# > Predicted = $262.0, Actual = $312.0
# > Predicted = $2132.0, Actual = $1443.0
# > Predicted = $458.0, Actual = $394.0
# > Predicted = $1547.0, Actual = $1655.0
# > Predicted = $1456.0, Actual = $1279.0
# > Predicted = $1147.0, Actual = $1446.0
# > Predicted = $1146.0, Actual = $968.0
# > Predicted = $1707.0, Actual = $2250.0
# > Predicted = $1299.0, Actual = $1114.0
# > Predicted = $383.0, Actual = $393.0
# > Predicted = $1635.0, Actual = $1664.0
# > Predicted = $998.0, Actual = $1296.0
# > Predicted = $2645.0, Actual = $2139.0
# > Predicted = $2350.0, Actual = $2498.0
# > Predicted = $2115.0, Actual = $1198.0
# > Predicted = $2019.0, Actual = $1839.0
# > Predicted = $1423.0, Actual = $1335.0
# > Predicted = $835.0, Actual = $815.0
# > Predicted = $1012.0, Actual = $812.0
# > Predicted = $1518.0, Actual = $1336.0
# > Predicted = $1403.0, Actual = $1330.0
# > Predicted = $610.0, Actual = $628.0
# > Predicted = $490.0, Actual = $780.0
# > Predicted = $3160.0, Actual = $3884.0
# > Predicted = $1996.0, Actual = $1250.0
# > Predicted = $649.0, Actual = $1306.0
# > Predicted = $1958.0, Actual = $2876.0
# > Predicted = $643.0, Actual = $791.0
# > Predicted = $780.0, Actual = $513.0
# > Predicted = $493.0, Actual = $825.0
# > Predicted = $2069.0, Actual = $2001.0
# > Predicted = $460.0, Actual = $629.0
# > Predicted = $863.0, Actual = $808.0
# > Predicted = $2563.0, Actual = $1252.0
# > Predicted = $2586.0, Actual = $3291.0
# > Predicted = $761.0, Actual = $727.0
# > Predicted = $973.0, Actual = $867.0
# > Predicted = $1277.0, Actual = $1851.0
# > Predicted = $2448.0, Actual = $2914.0
# > Predicted = $2416.0, Actual = $2027.0
# > Predicted = $1611.0, Actual = $1277.0
# > Predicted = $675.0, Actual = $680.0
# > Predicted = $752.0, Actual = $762.0
# > Predicted = $1572.0, Actual = $1647.0
# > Predicted = $843.0, Actual = $1267.0
# > Predicted = $2243.0, Actual = $1918.0
# > Predicted = $1862.0, Actual = $1307.0
# > Predicted = $1065.0, Actual = $852.0
# > Predicted = $1931.0, Actual = $1761.0
# > Predicted = $658.0, Actual = $912.0
# > Predicted = $534.0, Actual = $603.0
# > Predicted = $503.0, Actual = $353.0
# > Predicted = $1713.0, Actual = $2099.0
# > Predicted = $1598.0, Actual = $1147.0
# > Predicted = $1116.0, Actual = $1072.0
# > Predicted = $304.0, Actual = $599.0
# > Predicted = $1518.0, Actual = $1329.0
# > Predicted = $1532.0, Actual = $1642.0
# > Predicted = $761.0, Actual = $1279.0
# > Predicted = $1891.0, Actual = $2558.0
# > Predicted = $841.0, Actual = $837.0
# > Predicted = $1358.0, Actual = $2976.0
# > Predicted = $1192.0, Actual = $888.0
# > Predicted = $595.0, Actual = $607.0
# > Predicted = $1435.0, Actual = $1376.0
# > Predicted = $1511.0, Actual = $1431.0
# > Predicted = $1472.0, Actual = $1232.0
# > Predicted = $633.0, Actual = $900.0
# > Predicted = $432.0, Actual = $637.0
# > Predicted = $1601.0, Actual = $1446.0
# > Predicted = $2121.0, Actual = $1741.0
# > Predicted = $625.0, Actual = $780.0
# > Predicted = $1046.0, Actual = $1121.0
# > Predicted = $1089.0, Actual = $1287.0
# > Predicted = $1914.0, Actual = $2377.0
# > Predicted = $1500.0, Actual = $1082.0
# > Predicted = $1748.0, Actual = $1199.0
# > Predicted = $2143.0, Actual = $1907.0
# > Predicted = $1615.0, Actual = $1412.0
# > Predicted = $406.0, Actual = $593.0
# > Predicted = $422.0, Actual = $266.0
# > Predicted = $310.0, Actual = $297.0
# > Predicted = $2691.0, Actual = $2362.0
# > Predicted = $1895.0, Actual = $1433.0
# > Predicted = $727.0, Actual = $719.0
# > Predicted = $193.0, Actual = $225.0
# > Predicted = $1268.0, Actual = $948.0
# > Predicted = $567.0, Actual = $1363.0
# > Predicted = $2941.0, Actual = $3244.0
# > Predicted = $578.0, Actual = $602.0
# > Predicted = $451.0, Actual = $441.0
# > Predicted = $1525.0, Actual = $2235.0
# > Predicted = $1483.0, Actual = $1619.0
# > Predicted = $917.0, Actual = $903.0
# > Predicted = $758.0, Actual = $923.0
# > Predicted = $2202.0, Actual = $2153.0
# > Predicted = $1507.0, Actual = $1168.0
# > Predicted = $487.0, Actual = $634.0
# > Predicted = $1066.0, Actual = $779.0
# > Predicted = $2168.0, Actual = $1655.0
# > Predicted = $1154.0, Actual = $986.0
# > Predicted = $466.0, Actual = $470.0
# > Predicted = $3165.0, Actual = $2727.0
# > Predicted = $647.0, Actual = $514.0
# > Predicted = $1280.0, Actual = $957.0
# > Predicted = $530.0, Actual = $365.0
# > Predicted = $521.0, Actual = $718.0
# > Predicted = $2006.0, Actual = $1481.0
# > Predicted = $1591.0, Actual = $1466.0
# > Predicted = $2931.0, Actual = $2739.0
# > Predicted = $354.0, Actual = $326.0
# > Predicted = $855.0, Actual = $745.0
# > Predicted = $3237.0, Actual = $3376.0
# > Predicted = $808.0, Actual = $1190.0
# > Predicted = $1347.0, Actual = $1255.0
# > Predicted = $1155.0, Actual = $1264.0
# > Predicted = $957.0, Actual = $990.0
# > Predicted = $1865.0, Actual = $2051.0
# > Predicted = $1565.0, Actual = $1559.0
# > Predicted = $3504.0, Actual = $4301.0
# > Predicted = $884.0, Actual = $1458.0
# > Predicted = $1701.0, Actual = $1669.0
# > Predicted = $1568.0, Actual = $1927.0
# > Predicted = $1755.0, Actual = $1339.0
# > Predicted = $1750.0, Actual = $1513.0
# > Predicted = $2501.0, Actual = $2667.0
# > Predicted = $1897.0, Actual = $1877.0
# > Predicted = $219.0, Actual = $258.0
# > Predicted = $1630.0, Actual = $2647.0
# > Predicted = $2613.0, Actual = $2462.0
# > Predicted = $1176.0, Actual = $1520.0
# > Predicted = $503.0, Actual = $820.0
# > Predicted = $1776.0, Actual = $2048.0
# > Predicted = $1130.0, Actual = $1894.0
# > Predicted = $852.0, Actual = $761.0
# > Predicted = $411.0, Actual = $724.0
# > Predicted = $845.0, Actual = $854.0
# > Predicted = $993.0, Actual = $1241.0
# > Predicted = $2599.0, Actual = $1970.0
# > Predicted = $2835.0, Actual = $3106.0
# > Predicted = $1484.0, Actual = $1266.0
# > Predicted = $1589.0, Actual = $1762.0
# > Predicted = $1427.0, Actual = $1477.0
# > Predicted = $582.0, Actual = $936.0
# > Predicted = $434.0, Actual = $668.0
# > Predicted = $1229.0, Actual = $774.0
# > Predicted = $884.0, Actual = $846.0
# > Predicted = $1422.0, Actual = $1324.0
# > Predicted = $2363.0, Actual = $2809.0
# > Predicted = $1291.0, Actual = $1226.0
# > Predicted = $727.0, Actual = $880.0
# > Predicted = $982.0, Actual = $764.0
# > Predicted = $1611.0, Actual = $1059.0
# > Predicted = $735.0, Actual = $968.0
# > Predicted = $1128.0, Actual = $727.0
# > Predicted = $665.0, Actual = $595.0
# > Predicted = $902.0, Actual = $432.0
# > Predicted = $561.0, Actual = $616.0
# > Predicted = $583.0, Actual = $763.0
# > Predicted = $1163.0, Actual = $887.0
# > Predicted = $916.0, Actual = $1751.0
# > Predicted = $1418.0, Actual = $2160.0
# > Predicted = $2123.0, Actual = $1841.0
# > Predicted = $2456.0, Actual = $3745.0
# > Predicted = $1996.0, Actual = $1498.0
# > Predicted = $1174.0, Actual = $1034.0
# > Predicted = $2235.0, Actual = $2723.0
# > Predicted = $387.0, Actual = $346.0
# > Predicted = $1162.0, Actual = $1084.0
# > Predicted = $400.0, Actual = $501.0
# > Predicted = $916.0, Actual = $808.0
# > Predicted = $1509.0, Actual = $1581.0
# > Predicted = $332.0, Actual = $296.0
# > Predicted = $800.0, Actual = $860.0
# > Predicted = $707.0, Actual = $565.0
# > Predicted = $1668.0, Actual = $938.0
# > Predicted = $1971.0, Actual = $1266.0
# > Predicted = $1989.0, Actual = $1348.0
# > Predicted = $1542.0, Actual = $857.0
# > Predicted = $1061.0, Actual = $1153.0
# > Predicted = $565.0, Actual = $451.0
# > Predicted = $1778.0, Actual = $1607.0
# > Predicted = $4352.0, Actual = $3394.0
# > Predicted = $1713.0, Actual = $2414.0
# > Predicted = $1116.0, Actual = $1210.0
# > Predicted = $752.0, Actual = $442.0
# > Predicted = $1520.0, Actual = $1408.0
# > Predicted = $2191.0, Actual = $1790.0
# > Predicted = $2234.0, Actual = $3567.0
# > Predicted = $1630.0, Actual = $1710.0
# > Predicted = $911.0, Actual = $929.0
# > Predicted = $530.0, Actual = $472.0
# > Predicted = $1280.0, Actual = $756.0
# > Predicted = $1564.0, Actual = $1293.0
# > Predicted = $1199.0, Actual = $800.0
# > Predicted = $1936.0, Actual = $2124.0
# > Predicted = $323.0, Actual = $343.0
# > Predicted = $1020.0, Actual = $1003.0
# > Predicted = $1051.0, Actual = $820.0
# > Predicted = $1387.0, Actual = $1312.0
# > Predicted = $902.0, Actual = $519.0
# > Predicted = $1065.0, Actual = $656.0
# > Predicted = $2481.0, Actual = $2475.0
# > Predicted = $862.0, Actual = $772.0
# > Predicted = $1708.0, Actual = $1828.0
# > Predicted = $1698.0, Actual = $1234.0
# > Predicted = $1209.0, Actual = $1327.0
# > Predicted = $1521.0, Actual = $1451.0
# > Predicted = $895.0, Actual = $1064.0
# > Predicted = $984.0, Actual = $1309.0
# > Predicted = $1151.0, Actual = $1029.0
# > Predicted = $979.0, Actual = $878.0
# > Predicted = $1815.0, Actual = $1160.0
# > Predicted = $1210.0, Actual = $1270.0
# > Predicted = $1539.0, Actual = $1550.0
# > Predicted = $2121.0, Actual = $1620.0
# > Predicted = $966.0, Actual = $733.0
# > Predicted = $2100.0, Actual = $1923.0
# > Predicted = $4432.0, Actual = $4805.0
# > Predicted = $694.0, Actual = $276.0
# > Predicted = $2800.0, Actual = $3472.0
# > Predicted = $1203.0, Actual = $1437.0
# > Predicted = $2735.0, Actual = $2432.0
# > Predicted = $923.0, Actual = $764.0
# > Predicted = $3506.0, Actual = $2603.0
# > Predicted = $1173.0, Actual = $1708.0
# > Predicted = $169.0, Actual = $288.0
# > Predicted = $704.0, Actual = $1253.0
# > Predicted = $1046.0, Actual = $702.0
# > Predicted = $656.0, Actual = $581.0
# > Predicted = $456.0, Actual = $778.0
# > Predicted = $1610.0, Actual = $1977.0
# > Predicted = $1481.0, Actual = $1516.0
# > Predicted = $662.0, Actual = $783.0
# > Predicted = $538.0, Actual = $222.0
# > Predicted = $759.0, Actual = $541.0
# > Predicted = $1223.0, Actual = $1384.0
# > Predicted = $657.0, Actual = $833.0
# > Predicted = $496.0, Actual = $468.0
# > Predicted = $717.0, Actual = $783.0
# > Predicted = $1355.0, Actual = $1333.0
# > Predicted = $389.0, Actual = $362.0
# > Predicted = $514.0, Actual = $636.0
# > Predicted = $1773.0, Actual = $1709.0
# > Predicted = $508.0, Actual = $1048.0
# > Predicted = $1300.0, Actual = $1012.0
# > Predicted = $1574.0, Actual = $1678.0
# > Predicted = $172.0, Actual = $270.0
# > Predicted = $596.0, Actual = $566.0
# > Predicted = $826.0, Actual = $914.0
# > Predicted = $1768.0, Actual = $1762.0
# > Predicted = $1354.0, Actual = $1443.0
# > Predicted = $427.0, Actual = $1135.0
# > Predicted = $533.0, Actual = $399.0
# > Predicted = $793.0, Actual = $1210.0
# > Predicted = $912.0, Actual = $1273.0
# > Predicted = $880.0, Actual = $866.0
# > Predicted = $284.0, Actual = $360.0
# > Predicted = $731.0, Actual = $477.0
# > Predicted = $1285.0, Actual = $1252.0
# > Predicted = $1640.0, Actual = $1676.0
# > Predicted = $1985.0, Actual = $1972.0
# > Predicted = $2988.0, Actual = $3637.0
# > Predicted = $882.0, Actual = $727.0
# > Predicted = $971.0, Actual = $2108.0
# > Predicted = $2738.0, Actual = $2666.0
# > Predicted = $809.0, Actual = $775.0
# > Predicted = $381.0, Actual = $439.0
# > Predicted = $1185.0, Actual = $1136.0
# > Predicted = $2507.0, Actual = $3685.0
# > Predicted = $1343.0, Actual = $1384.0
# > Predicted = $581.0, Actual = $589.0
# > Predicted = $522.0, Actual = $795.0
# > Predicted = $1859.0, Actual = $1482.0
# > Predicted = $838.0, Actual = $806.0
# > Predicted = $742.0, Actual = $631.0
# > Predicted = $1457.0, Actual = $1836.0
# > Predicted = $937.0, Actual = $746.0
# > Predicted = $3018.0, Actual = $3013.0
# > Predicted = $717.0, Actual = $496.0
# > Predicted = $1073.0, Actual = $1589.0
# > Predicted = $2266.0, Actual = $2033.0
# > Predicted = $1274.0, Actual = $1091.0
# > Predicted = $1287.0, Actual = $1322.0
# > Predicted = $1599.0, Actual = $1692.0
# > Predicted = $1347.0, Actual = $1184.0
# > Predicted = $617.0, Actual = $766.0
# > Predicted = $1973.0, Actual = $1793.0
# > Predicted = $414.0, Actual = $245.0
# > Predicted = $1823.0, Actual = $1752.0
# > Predicted = $874.0, Actual = $876.0
# > Predicted = $646.0, Actual = $716.0
# > Predicted = $800.0, Actual = $833.0
# > Predicted = $852.0, Actual = $855.0
# > Predicted = $639.0, Actual = $1629.0
# > Predicted = $616.0, Actual = $960.0
# > Predicted = $1042.0, Actual = $1136.0
# > Predicted = $2167.0, Actual = $2017.0
# > Predicted = $1131.0, Actual = $1283.0
# > Predicted = $1023.0, Actual = $1010.0
# > Predicted = $695.0, Actual = $534.0
# > Predicted = $650.0, Actual = $685.0
# > Predicted = $1643.0, Actual = $1612.0
# > Predicted = $692.0, Actual = $558.0
# > Predicted = $788.0, Actual = $742.0
# > Predicted = $3059.0, Actual = $3451.0
# > Predicted = $728.0, Actual = $712.0
# > Predicted = $3622.0, Actual = $4422.0
# > Predicted = $982.0, Actual = $771.0
# > Predicted = $1162.0, Actual = $809.0
# > Predicted = $1332.0, Actual = $1655.0
# > Predicted = $1286.0, Actual = $1046.0
# > Predicted = $580.0, Actual = $480.0
# > Predicted = $259.0, Actual = $537.0
# > Predicted = $265.0, Actual = $256.0
# > Predicted = $492.0, Actual = $536.0
# > Predicted = $1181.0, Actual = $1203.0
# > Predicted = $1634.0, Actual = $1868.0
# > Predicted = $905.0, Actual = $694.0
# > Predicted = $463.0, Actual = $991.0
# > Predicted = $500.0, Actual = $590.0
# > Predicted = $2172.0, Actual = $1455.0
# > Predicted = $3643.0, Actual = $2381.0
# > Predicted = $1493.0, Actual = $1602.0
# > Predicted = $514.0, Actual = $605.0
# > Predicted = $502.0, Actual = $464.0
# > Predicted = $1403.0, Actual = $1069.0
# > Predicted = $2605.0, Actual = $2194.0
# > Predicted = $1776.0, Actual = $1471.0
# > Predicted = $269.0, Actual = $188.0
# > Predicted = $1668.0, Actual = $3790.0
# > Predicted = $1209.0, Actual = $1843.0
# > Predicted = $760.0, Actual = $841.0
# > Predicted = $1766.0, Actual = $1736.0
# > Predicted = $880.0, Actual = $1380.0
# > Predicted = $1680.0, Actual = $1140.0
# > Predicted = $646.0, Actual = $553.0
# > Predicted = $867.0, Actual = $758.0
# > Predicted = $907.0, Actual = $896.0
# > Predicted = $494.0, Actual = $509.0
# > Predicted = $1069.0, Actual = $1014.0
# > Predicted = $2033.0, Actual = $1588.0
# > Predicted = $1415.0, Actual = $1521.0
# > Predicted = $475.0, Actual = $929.0
# > Predicted = $1266.0, Actual = $1067.0
# > Predicted = $1259.0, Actual = $1251.0
# > Predicted = $557.0, Actual = $562.0
# > Predicted = $204.0, Actual = $303.0
# > Predicted = $720.0, Actual = $768.0
# > Predicted = $1218.0, Actual = $1235.0
# > Predicted = $1357.0, Actual = $1264.0
# > Predicted = $1241.0, Actual = $876.0
# > Predicted = $2340.0, Actual = $2473.0
# > Predicted = $1518.0, Actual = $1372.0
# > Predicted = $1826.0, Actual = $2323.0
# > Predicted = $2759.0, Actual = $2723.0
# > Predicted = $1755.0, Actual = $1964.0
# > Predicted = $698.0, Actual = $669.0
# > Predicted = $1970.0, Actual = $3764.0
# > Predicted = $1750.0, Actual = $1492.0
# > Predicted = $896.0, Actual = $1096.0
# > Predicted = $2506.0, Actual = $2220.0
# > Predicted = $2286.0, Actual = $1756.0
# > Predicted = $2465.0, Actual = $1471.0
# > Predicted = $609.0, Actual = $843.0
# > Predicted = $1734.0, Actual = $968.0
# > Predicted = $2625.0, Actual = $2033.0
# > Predicted = $685.0, Actual = $482.0
# > Predicted = $940.0, Actual = $1208.0
# > Predicted = $1845.0, Actual = $1664.0
# > Predicted = $3767.0, Actual = $4311.0
# > Predicted = $2830.0, Actual = $2815.0
# > Predicted = $918.0, Actual = $779.0
# > Predicted = $3230.0, Actual = $3175.0
# > Predicted = $1913.0, Actual = $1895.0
# > Predicted = $1200.0, Actual = $2117.0
# > Predicted = $1408.0, Actual = $1868.0
# > Predicted = $930.0, Actual = $1072.0
# > Predicted = $1483.0, Actual = $1727.0
# > Predicted = $2713.0, Actual = $2351.0
# > Predicted = $2186.0, Actual = $2094.0
# > Predicted = $451.0, Actual = $719.0
# > Predicted = $934.0, Actual = $964.0
# > Predicted = $1024.0, Actual = $1284.0
# > Predicted = $920.0, Actual = $1393.0
# > Predicted = $1056.0, Actual = $1047.0
# > Predicted = $2869.0, Actual = $1596.0
# > Predicted = $1505.0, Actual = $1408.0
# > Predicted = $812.0, Actual = $1084.0
# > Predicted = $756.0, Actual = $1207.0
# > Predicted = $1364.0, Actual = $1404.0
# > Predicted = $1051.0, Actual = $892.0
# > Predicted = $1228.0, Actual = $1148.0
# > Predicted = $1217.0, Actual = $1746.0
# > Predicted = $1074.0, Actual = $957.0
# > Predicted = $1827.0, Actual = $2575.0
# > Predicted = $3157.0, Actual = $3361.0
# > Predicted = $499.0, Actual = $574.0
# > Predicted = $1484.0, Actual = $1468.0
# > Predicted = $335.0, Actual = $326.0
# > Predicted = $633.0, Actual = $785.0
# > Predicted = $2629.0, Actual = $3089.0
# > Predicted = $966.0, Actual = $670.0
# > Predicted = $1097.0, Actual = $921.0
# > Predicted = $1397.0, Actual = $1225.0
# > Predicted = $351.0, Actual = $451.0
# > Predicted = $1047.0, Actual = $714.0
# > Predicted = $923.0, Actual = $682.0
# > Predicted = $1366.0, Actual = $1292.0
# > Predicted = $1103.0, Actual = $695.0
# > Predicted = $1695.0, Actual = $894.0
# > Predicted = $1417.0, Actual = $1759.0
# > Predicted = $968.0, Actual = $1240.0
# > Predicted = $479.0, Actual = $595.0
# > Predicted = $3365.0, Actual = $3588.0
# > Predicted = $2234.0, Actual = $1632.0
# > Predicted = $3600.0, Actual = $3059.0
# > Predicted = $1228.0, Actual = $1621.0
# > Predicted = $1455.0, Actual = $1602.0
# > Predicted = $1008.0, Actual = $886.0
# > Predicted = $2183.0, Actual = $2041.0
# > Predicted = $731.0, Actual = $791.0
# > Predicted = $765.0, Actual = $691.0
# > Predicted = $470.0, Actual = $304.0
# > Predicted = $2609.0, Actual = $3100.0
# > Predicted = $737.0, Actual = $608.0
# > Predicted = $273.0, Actual = $445.0
# > Predicted = $769.0, Actual = $292.0
# > Predicted = $1131.0, Actual = $505.0
# > Predicted = $234.0, Actual = $301.0
# > Predicted = $2647.0, Actual = $2685.0
# > Predicted = $1209.0, Actual = $985.0
# > Predicted = $2510.0, Actual = $2072.0
# > Predicted = $1825.0, Actual = $1639.0
# > Predicted = $1842.0, Actual = $1870.0
# > Predicted = $1314.0, Actual = $1277.0
# > Predicted = $236.0, Actual = $88.0
# > Predicted = $179.0, Actual = $271.0
# > Predicted = $2117.0, Actual = $1395.0
# > Predicted = $1415.0, Actual = $1229.0
# > Predicted = $466.0, Actual = $575.0
# > Predicted = $362.0, Actual = $328.0
# > Predicted = $1685.0, Actual = $1793.0
# > Predicted = $677.0, Actual = $854.0
# > Predicted = $1116.0, Actual = $1332.0
# > Predicted = $548.0, Actual = $629.0
# > Predicted = $2184.0, Actual = $1732.0
# > Predicted = $530.0, Actual = $954.0
# > Predicted = $769.0, Actual = $972.0
# > Predicted = $1927.0, Actual = $1051.0
# > Predicted = $2507.0, Actual = $3062.0
# > Predicted = $788.0, Actual = $1062.0
# > Predicted = $2054.0, Actual = $1628.0
# > Predicted = $864.0, Actual = $780.0
# > Predicted = $928.0, Actual = $1189.0
# > Predicted = $3561.0, Actual = $5832.0
# > Predicted = $832.0, Actual = $496.0
# > Predicted = $699.0, Actual = $442.0
# > Predicted = $743.0, Actual = $852.0
# > Predicted = $565.0, Actual = $451.0
# > Predicted = $1047.0, Actual = $1267.0
# > Predicted = $2212.0, Actual = $1648.0
# > Predicted = $1063.0, Actual = $1019.0
# > Predicted = $570.0, Actual = $422.0
# > Predicted = $1308.0, Actual = $976.0
# > Predicted = $2113.0, Actual = $3209.0
# > Predicted = $1093.0, Actual = $1095.0
# > Predicted = $899.0, Actual = $949.0
# > Predicted = $1848.0, Actual = $1568.0
# > Predicted = $1765.0, Actual = $1960.0
# > Predicted = $1494.0, Actual = $1410.0
# > Predicted = $1042.0, Actual = $1154.0
# > Predicted = $2557.0, Actual = $2089.0
# > Predicted = $473.0, Actual = $423.0
# > Predicted = $1503.0, Actual = $879.0
# > Predicted = $1172.0, Actual = $816.0
# > Predicted = $1055.0, Actual = $969.0
# > Predicted = $1199.0, Actual = $1286.0
# > Predicted = $761.0, Actual = $930.0
# > Predicted = $1170.0, Actual = $1188.0
# > Predicted = $3741.0, Actual = $2803.0
# > Predicted = $1610.0, Actual = $2368.0
# > Predicted = $0.0, Actual = $67.0
# > Predicted = $1238.0, Actual = $1400.0
# > Predicted = $574.0, Actual = $772.0
# > Predicted = $2630.0, Actual = $1218.0
# > Predicted = $394.0, Actual = $397.0
# > Predicted = $1274.0, Actual = $1409.0
# > Predicted = $1426.0, Actual = $1387.0
# > Predicted = $1377.0, Actual = $1297.0
# > Predicted = $611.0, Actual = $689.0
# > Predicted = $188.0, Actual = $191.0
# > Predicted = $1401.0, Actual = $1095.0
# > Predicted = $931.0, Actual = $1017.0
# > Predicted = $1755.0, Actual = $1420.0
# > Predicted = $727.0, Actual = $868.0
# > Predicted = $2372.0, Actual = $2385.0
# > Predicted = $1860.0, Actual = $1995.0
# > Predicted = $568.0, Actual = $646.0
# > Predicted = $2830.0, Actual = $5549.0
# > Predicted = $1698.0, Actual = $1508.0
# > Predicted = $2250.0, Actual = $1989.0
# > Predicted = $902.0, Actual = $773.0
# > Predicted = $217.0, Actual = $198.0
# > Predicted = $1086.0, Actual = $1295.0
# > Predicted = $529.0, Actual = $1189.0
# > Predicted = $599.0, Actual = $960.0
# > Predicted = $973.0, Actual = $1086.0
# > Predicted = $1692.0, Actual = $1789.0
# > Predicted = $1263.0, Actual = $1283.0
# > Predicted = $893.0, Actual = $805.0
# > Predicted = $2283.0, Actual = $2114.0
# > Predicted = $923.0, Actual = $1115.0
# > Predicted = $739.0, Actual = $594.0
# > Predicted = $1795.0, Actual = $2517.0
# > Predicted = $1303.0, Actual = $1017.0
# > Predicted = $2229.0, Actual = $2271.0
# > Predicted = $1351.0, Actual = $1387.0
# > Predicted = $1287.0, Actual = $1286.0
# > Predicted = $679.0, Actual = $861.0
# > Predicted = $2084.0, Actual = $1580.0
# > Predicted = $1765.0, Actual = $2139.0
# > Predicted = $2502.0, Actual = $2324.0
# > Predicted = $2636.0, Actual = $2698.0
# > Predicted = $463.0, Actual = $594.0
# > Predicted = $1039.0, Actual = $630.0
# > Predicted = $1864.0, Actual = $1419.0
# > Predicted = $1102.0, Actual = $948.0
# > Predicted = $351.0, Actual = $436.0
# > Predicted = $1906.0, Actual = $2304.0
# > Predicted = $1483.0, Actual = $916.0
# > Predicted = $862.0, Actual = $1560.0
# > Predicted = $1205.0, Actual = $730.0
# > Predicted = $1648.0, Actual = $2056.0
# > Predicted = $1278.0, Actual = $1547.0
# > Predicted = $1563.0, Actual = $1624.0
# > Predicted = $812.0, Actual = $860.0
# > Predicted = $3294.0, Actual = $3387.0
# > Predicted = $764.0, Actual = $840.0
# > Predicted = $923.0, Actual = $898.0
# > Predicted = $1546.0, Actual = $1443.0
# > Predicted = $1589.0, Actual = $1417.0
# > Predicted = $976.0, Actual = $916.0
# > Predicted = $585.0, Actual = $1062.0
# > Predicted = $2800.0, Actual = $2717.0
# > Predicted = $1625.0, Actual = $1871.0
# > Predicted = $1184.0, Actual = $709.0
# > Predicted = $306.0, Actual = $315.0
# > Predicted = $1488.0, Actual = $1354.0
# > Predicted = $2289.0, Actual = $1365.0
# > Predicted = $749.0, Actual = $562.0
# > Predicted = $2467.0, Actual = $2274.0
# > Predicted = $2935.0, Actual = $2483.0
# > Predicted = $472.0, Actual = $417.0
# > Predicted = $1025.0, Actual = $1166.0
# > Predicted = $387.0, Actual = $285.0
# > Predicted = $1456.0, Actual = $1510.0
# > Predicted = $1602.0, Actual = $1730.0
# > Predicted = $262.0, Actual = $231.0
# > Predicted = $1054.0, Actual = $1112.0
# > Predicted = $2123.0, Actual = $2513.0
# > Predicted = $1405.0, Actual = $1113.0
# > Predicted = $857.0, Actual = $958.0
# > Predicted = $1087.0, Actual = $862.0
# > Predicted = $792.0, Actual = $761.0
# > Predicted = $1454.0, Actual = $1270.0
# > Predicted = $2354.0, Actual = $2210.0
# > Predicted = $1408.0, Actual = $1243.0
# > Predicted = $792.0, Actual = $1428.0
# > Predicted = $696.0, Actual = $528.0
# > Predicted = $4661.0, Actual = $2907.0
# > Predicted = $1327.0, Actual = $1596.0
# > Predicted = $1046.0, Actual = $1101.0
# > Predicted = $1868.0, Actual = $1887.0
# > Predicted = $1871.0, Actual = $1745.0
# > Predicted = $1423.0, Actual = $1303.0
# > Predicted = $3651.0, Actual = $3791.0
# > Predicted = $1255.0, Actual = $1301.0
# > Predicted = $1411.0, Actual = $1072.0
# > Predicted = $1251.0, Actual = $986.0
# > Predicted = $291.0, Actual = $294.0
# > Predicted = $1102.0, Actual = $1058.0
# > Predicted = $1016.0, Actual = $1241.0
# > Predicted = $828.0, Actual = $451.0
# > Predicted = $1203.0, Actual = $1119.0
# > Predicted = $688.0, Actual = $741.0
# > Predicted = $2144.0, Actual = $2078.0
# > Predicted = $1842.0, Actual = $1689.0
# > Predicted = $650.0, Actual = $730.0
# > Predicted = $1621.0, Actual = $2337.0
# > Predicted = $3441.0, Actual = $3346.0
# > Predicted = $1707.0, Actual = $2224.0
# > Predicted = $664.0, Actual = $699.0
# > Predicted = $1874.0, Actual = $2232.0
# > Predicted = $898.0, Actual = $906.0
# > Predicted = $3246.0, Actual = $3581.0
# > Predicted = $2959.0, Actual = $1608.0
# > Predicted = $1358.0, Actual = $1253.0
# > Predicted = $1782.0, Actual = $1586.0
# > Predicted = $1610.0, Actual = $1138.0
# > Predicted = $1558.0, Actual = $1825.0
# > Predicted = $3131.0, Actual = $2996.0
# > Predicted = $247.0, Actual = $307.0
# > Predicted = $877.0, Actual = $916.0
# > Predicted = $1387.0, Actual = $1435.0
# > Predicted = $1300.0, Actual = $1397.0
# > Predicted = $693.0, Actual = $1392.0
# > Predicted = $1022.0, Actual = $582.0
# > Predicted = $855.0, Actual = $959.0
# > Predicted = $1778.0, Actual = $1515.0
# > Predicted = $1022.0, Actual = $1396.0
# > Predicted = $1810.0, Actual = $2014.0
# > Predicted = $1695.0, Actual = $1397.0
# > Predicted = $2338.0, Actual = $1346.0
# > Predicted = $462.0, Actual = $414.0
# > Predicted = $3401.0, Actual = $2907.0
# > Predicted = $425.0, Actual = $321.0
# > Predicted = $979.0, Actual = $1140.0
# > Predicted = $1056.0, Actual = $1016.0
# > Predicted = $1042.0, Actual = $1064.0
# > Predicted = $3817.0, Actual = $4041.0
# > Predicted = $3047.0, Actual = $3709.0
# > Predicted = $973.0, Actual = $761.0
# > Predicted = $981.0, Actual = $1096.0
# > Predicted = $1042.0, Actual = $1334.0
# > Predicted = $1319.0, Actual = $1527.0
# > Predicted = $1248.0, Actual = $988.0
# > Predicted = $956.0, Actual = $896.0
# > Predicted = $1823.0, Actual = $2018.0
# > Predicted = $1070.0, Actual = $1247.0
# > Predicted = $1672.0, Actual = $1637.0
# > Predicted = $3077.0, Actual = $2213.0
# > Predicted = $601.0, Actual = $488.0
# > Predicted = $706.0, Actual = $1002.0
# > Predicted = $754.0, Actual = $904.0
# > Predicted = $150.0, Actual = $214.0
# > Predicted = $831.0, Actual = $907.0
# > Predicted = $2061.0, Actual = $2143.0
# > Predicted = $1487.0, Actual = $1741.0
# > Predicted = $3504.0, Actual = $2103.0
# > Predicted = $1816.0, Actual = $1327.0
# > Predicted = $701.0, Actual = $731.0
# > Predicted = $1037.0, Actual = $1051.0
# > Predicted = $271.0, Actual = $304.0
# > Predicted = $1804.0, Actual = $2482.0
# > Predicted = $1510.0, Actual = $697.0
# > Predicted = $952.0, Actual = $911.0
# > Predicted = $1897.0, Actual = $1956.0
# > Predicted = $1058.0, Actual = $921.0
# > Predicted = $2186.0, Actual = $1542.0
# > Predicted = $2970.0, Actual = $2487.0
# > Predicted = $241.0, Actual = $320.0
# > Predicted = $2251.0, Actual = $2972.0
# > Predicted = $3026.0, Actual = $3728.0
# > Predicted = $2384.0, Actual = $2174.0
# > Predicted = $2637.0, Actual = $2794.0
# > Predicted = $1662.0, Actual = $2801.0
# > Predicted = $1601.0, Actual = $1362.0
# > Predicted = $942.0, Actual = $944.0
# > Predicted = $933.0, Actual = $1203.0
# > Predicted = $784.0, Actual = $700.0
# > Predicted = $1299.0, Actual = $1430.0
# > Predicted = $704.0, Actual = $1060.0
# > Predicted = $1075.0, Actual = $1041.0
# > Predicted = $1144.0, Actual = $1245.0
# > Predicted = $2637.0, Actual = $2758.0
# > Predicted = $190.0, Actual = $278.0
# > Predicted = $1132.0, Actual = $1130.0
# > Predicted = $1630.0, Actual = $2796.0
# > Predicted = $1636.0, Actual = $1541.0
# > Predicted = $773.0, Actual = $875.0
# > Predicted = $1987.0, Actual = $1968.0
# > Predicted = $1012.0, Actual = $1208.0
# > Predicted = $2249.0, Actual = $1496.0
# > Predicted = $1681.0, Actual = $1617.0
# > Predicted = $3677.0, Actual = $2050.0
# > Predicted = $756.0, Actual = $745.0
# > Predicted = $862.0, Actual = $1033.0
# > Predicted = $432.0, Actual = $544.0
# > Predicted = $803.0, Actual = $993.0
# > Predicted = $1693.0, Actual = $1946.0
# > Predicted = $1039.0, Actual = $1166.0
# > Predicted = $650.0, Actual = $749.0
# > Predicted = $1489.0, Actual = $1198.0
# > Predicted = $375.0, Actual = $659.0
# > Predicted = $930.0, Actual = $1184.0
# > Predicted = $341.0, Actual = $428.0
# > Predicted = $2090.0, Actual = $2091.0
# > Predicted = $1150.0, Actual = $1185.0
# > Predicted = $1185.0, Actual = $1407.0
# > Predicted = $795.0, Actual = $650.0
# > Predicted = $1555.0, Actual = $1647.0
# > Predicted = $690.0, Actual = $910.0
# > Predicted = $1190.0, Actual = $1809.0
# > Predicted = $1536.0, Actual = $1768.0
# > Predicted = $720.0, Actual = $802.0
# > Predicted = $2548.0, Actual = $2113.0
# > Predicted = $1814.0, Actual = $1642.0
# > Predicted = $1277.0, Actual = $1243.0
# > Predicted = $677.0, Actual = $723.0
# > Predicted = $1230.0, Actual = $1419.0
# > Predicted = $832.0, Actual = $836.0
# > Predicted = $462.0, Actual = $375.0
# > Predicted = $1096.0, Actual = $1093.0
# > Predicted = $1978.0, Actual = $1690.0
# > Predicted = $2377.0, Actual = $2269.0
# > Predicted = $1948.0, Actual = $2456.0
# > Predicted = $1313.0, Actual = $1331.0
# > Predicted = $834.0, Actual = $1718.0
# > Predicted = $1906.0, Actual = $1621.0
# > Predicted = $2804.0, Actual = $3838.0
# > Predicted = $2686.0, Actual = $3245.0
# > Predicted = $2498.0, Actual = $2836.0
# > Predicted = $1106.0, Actual = $1326.0
# > Predicted = $1752.0, Actual = $1522.0
# > Predicted = $699.0, Actual = $456.0
# > Predicted = $1836.0, Actual = $1745.0
# > Predicted = $403.0, Actual = $468.0
# > Predicted = $288.0, Actual = $307.0
# > Predicted = $1092.0, Actual = $1181.0
# > Predicted = $1121.0, Actual = $1676.0
# > Predicted = $593.0, Actual = $764.0
# > Predicted = $1738.0, Actual = $1879.0
# > Predicted = $753.0, Actual = $634.0
# > Predicted = $1749.0, Actual = $1553.0
# > Predicted = $2820.0, Actual = $2710.0
# > Predicted = $1035.0, Actual = $1395.0
# > Predicted = $1808.0, Actual = $2817.0
# > Predicted = $887.0, Actual = $896.0
# > Predicted = $851.0, Actual = $1028.0
# > Predicted = $815.0, Actual = $791.0
# > Predicted = $824.0, Actual = $1265.0
# > Predicted = $2524.0, Actual = $3145.0
# > Predicted = $1276.0, Actual = $1088.0
# > Predicted = $1609.0, Actual = $1516.0
# > Predicted = $824.0, Actual = $482.0
# > Predicted = $302.0, Actual = $299.0
# > Predicted = $830.0, Actual = $719.0
# > Predicted = $1768.0, Actual = $1573.0
# > Predicted = $1611.0, Actual = $2057.0
# > Predicted = $3410.0, Actual = $2921.0
# > Predicted = $793.0, Actual = $720.0
# > Predicted = $2974.0, Actual = $2613.0
# > Predicted = $1373.0, Actual = $1206.0
# > Predicted = $906.0, Actual = $686.0
# > Predicted = $3102.0, Actual = $2555.0
# > Predicted = $898.0, Actual = $885.0
# > Predicted = $1594.0, Actual = $1509.0
# > Predicted = $1187.0, Actual = $1077.0
# > Predicted = $2218.0, Actual = $1924.0
# > Predicted = $1450.0, Actual = $1189.0
# > Predicted = $1728.0, Actual = $1139.0
# > Predicted = $843.0, Actual = $856.0
# > Predicted = $1164.0, Actual = $1085.0
# > Predicted = $547.0, Actual = $465.0
# > Predicted = $2099.0, Actual = $2195.0
# > Predicted = $336.0, Actual = $321.0
# > Predicted = $1243.0, Actual = $858.0
# > Predicted = $2849.0, Actual = $2330.0
# > Predicted = $1170.0, Actual = $921.0
# > Predicted = $1470.0, Actual = $1961.0
# > Predicted = $457.0, Actual = $704.0
# > Predicted = $1797.0, Actual = $2070.0
# > Predicted = $865.0, Actual = $1153.0
# > Predicted = $460.0, Actual = $624.0
# > Predicted = $1441.0, Actual = $1781.0
# > Predicted = $1068.0, Actual = $717.0
# > Predicted = $978.0, Actual = $1000.0
# > Predicted = $1357.0, Actual = $1132.0
# > Predicted = $411.0, Actual = $586.0
# > Predicted = $772.0, Actual = $583.0
# > Predicted = $992.0, Actual = $1125.0
# > Predicted = $1758.0, Actual = $2470.0
# > Predicted = $779.0, Actual = $767.0
# > Predicted = $1079.0, Actual = $1399.0
# > Predicted = $1200.0, Actual = $1121.0
# > Predicted = $381.0, Actual = $325.0
# > Predicted = $585.0, Actual = $635.0
# > Predicted = $1507.0, Actual = $1172.0
# > Predicted = $1531.0, Actual = $1349.0
# > Predicted = $1347.0, Actual = $1861.0
# > Predicted = $681.0, Actual = $649.0
# > Predicted = $364.0, Actual = $477.0
# > Predicted = $757.0, Actual = $654.0
# > Predicted = $510.0, Actual = $630.0
# > Predicted = $719.0, Actual = $1125.0
# > Predicted = $1568.0, Actual = $1395.0
# > Predicted = $539.0, Actual = $416.0
# > Predicted = $2080.0, Actual = $1921.0
# > Predicted = $879.0, Actual = $1165.0
# > Predicted = $495.0, Actual = $459.0
# > Predicted = $250.0, Actual = $368.0
# > Predicted = $584.0, Actual = $562.0
# > Predicted = $925.0, Actual = $1105.0
# > Predicted = $1614.0, Actual = $1352.0
# > Predicted = $718.0, Actual = $1006.0
# > Predicted = $646.0, Actual = $794.0
# > Predicted = $976.0, Actual = $1135.0
# > Predicted = $2014.0, Actual = $2343.0
# > Predicted = $959.0, Actual = $681.0
# > Predicted = $1998.0, Actual = $2141.0
# > Predicted = $1518.0, Actual = $1813.0
# > Predicted = $2117.0, Actual = $2232.0
# > Predicted = $663.0, Actual = $828.0
# > Predicted = $736.0, Actual = $686.0
# > Predicted = $778.0, Actual = $1302.0
# > Predicted = $688.0, Actual = $841.0
# > Predicted = $4681.0, Actual = $4746.0
# > Predicted = $1532.0, Actual = $1628.0
# > Predicted = $1045.0, Actual = $984.0
# > Predicted = $928.0, Actual = $801.0
# > Predicted = $1680.0, Actual = $2336.0
# > Predicted = $2701.0, Actual = $2415.0
# > Predicted = $1752.0, Actual = $1371.0
# > Predicted = $289.0, Actual = $216.0
# > Predicted = $900.0, Actual = $872.0
# > Predicted = $1656.0, Actual = $1310.0
# > Predicted = $1182.0, Actual = $878.0
# > Predicted = $381.0, Actual = $308.0
# > Predicted = $802.0, Actual = $771.0
# > Predicted = $644.0, Actual = $1159.0
# > Predicted = $3048.0, Actual = $3750.0
# > Predicted = $2183.0, Actual = $2221.0
# > Predicted = $2090.0, Actual = $1772.0
# > Predicted = $1683.0, Actual = $2764.0
# > Predicted = $1872.0, Actual = $1576.0
# > Predicted = $633.0, Actual = $793.0
# > Predicted = $2445.0, Actual = $1153.0
# > Predicted = $1354.0, Actual = $2025.0
# > Predicted = $1205.0, Actual = $1264.0
# > Predicted = $1520.0, Actual = $1569.0
# > Predicted = $2162.0, Actual = $2453.0
# > Predicted = $877.0, Actual = $1132.0
# > Predicted = $828.0, Actual = $815.0
# > Predicted = $1440.0, Actual = $1719.0
# > Predicted = $903.0, Actual = $975.0
# > Predicted = $2366.0, Actual = $2141.0
# > Predicted = $2783.0, Actual = $2599.0
# > Predicted = $3561.0, Actual = $4880.0
# > Predicted = $933.0, Actual = $1171.0
# > Predicted = $965.0, Actual = $1260.0
# > Predicted = $1558.0, Actual = $2334.0
# > Predicted = $527.0, Actual = $377.0
# > Predicted = $1163.0, Actual = $1098.0
# > Predicted = $1493.0, Actual = $1225.0
# > Predicted = $619.0, Actual = $483.0
# > Predicted = $342.0, Actual = $312.0
# > Predicted = $1636.0, Actual = $1640.0
# > Predicted = $1302.0, Actual = $812.0
# > Predicted = $1419.0, Actual = $1773.0
# > Predicted = $1374.0, Actual = $1278.0
# > Predicted = $1513.0, Actual = $2039.0
# > Predicted = $788.0, Actual = $693.0
# > Predicted = $863.0, Actual = $682.0
# > Predicted = $613.0, Actual = $901.0
# > Predicted = $868.0, Actual = $997.0
# > Predicted = $816.0, Actual = $798.0
# > Predicted = $1159.0, Actual = $865.0
# > Predicted = $1340.0, Actual = $1476.0
# > Predicted = $2277.0, Actual = $2204.0
# > Predicted = $1988.0, Actual = $1740.0
# > Predicted = $2237.0, Actual = $1150.0
# > Predicted = $2183.0, Actual = $2446.0
# > Predicted = $1529.0, Actual = $1265.0
# > Predicted = $1205.0, Actual = $2450.0
# > Predicted = $1899.0, Actual = $2654.0
# > Predicted = $728.0, Actual = $992.0
# > Predicted = $975.0, Actual = $964.0
# > Predicted = $1290.0, Actual = $1036.0
# > Predicted = $1116.0, Actual = $1443.0
# > Predicted = $2605.0, Actual = $2668.0
# > Predicted = $876.0, Actual = $935.0
# > Predicted = $1619.0, Actual = $1576.0
# > Predicted = $1553.0, Actual = $1628.0
# > Predicted = $893.0, Actual = $698.0
# > Predicted = $502.0, Actual = $430.0
# > Predicted = $3669.0, Actual = $3828.0
# > Predicted = $422.0, Actual = $587.0
# > Predicted = $455.0, Actual = $878.0
# > Predicted = $1415.0, Actual = $1624.0
# > Predicted = $691.0, Actual = $936.0
# > Predicted = $1189.0, Actual = $1173.0
# > Predicted = $1528.0, Actual = $1607.0
# > Predicted = $847.0, Actual = $796.0
# > Predicted = $1140.0, Actual = $1479.0
# > Predicted = $832.0, Actual = $1158.0
# > Predicted = $1558.0, Actual = $773.0
# > Predicted = $1077.0, Actual = $403.0
# > Predicted = $1380.0, Actual = $1283.0
# > Predicted = $492.0, Actual = $612.0
# > Predicted = $2277.0, Actual = $2172.0
# > Predicted = $817.0, Actual = $902.0
# > Predicted = $1888.0, Actual = $2087.0
# > Predicted = $767.0, Actual = $633.0
# > Predicted = $1281.0, Actual = $956.0
# > Predicted = $1793.0, Actual = $1738.0
# > Predicted = $1851.0, Actual = $1664.0
# > Predicted = $1636.0, Actual = $1671.0
# > Predicted = $843.0, Actual = $834.0
# > Predicted = $860.0, Actual = $1201.0
# > Predicted = $898.0, Actual = $927.0
# > Predicted = $923.0, Actual = $868.0
# > Predicted = $1196.0, Actual = $855.0
# > Predicted = $714.0, Actual = $1564.0
# > Predicted = $2557.0, Actual = $2329.0
# > Predicted = $802.0, Actual = $839.0
# > Predicted = $1631.0, Actual = $2036.0
# > Predicted = $2503.0, Actual = $1457.0
# > Predicted = $2735.0, Actual = $2489.0
# > Predicted = $1180.0, Actual = $1012.0
# > Predicted = $716.0, Actual = $789.0
# > Predicted = $2515.0, Actual = $2358.0
# > Predicted = $896.0, Actual = $585.0
# > Predicted = $1689.0, Actual = $1473.0
# > Predicted = $599.0, Actual = $660.0
# > Predicted = $984.0, Actual = $1403.0
# > Predicted = $1196.0, Actual = $1101.0
# > Predicted = $3495.0, Actual = $3532.0
# > Predicted = $351.0, Actual = $323.0
# > Predicted = $855.0, Actual = $1114.0
# > Predicted = $732.0, Actual = $843.0
# > Predicted = $986.0, Actual = $965.0
# > Predicted = $555.0, Actual = $575.0
# > Predicted = $931.0, Actual = $1053.0
# > Predicted = $859.0, Actual = $628.0
# > Predicted = $1108.0, Actual = $790.0
# > Predicted = $1180.0, Actual = $963.0
# > Predicted = $1070.0, Actual = $1117.0
# > Predicted = $1451.0, Actual = $1395.0
# > Predicted = $1073.0, Actual = $1133.0
# Accuracy: 48.275862068965516
