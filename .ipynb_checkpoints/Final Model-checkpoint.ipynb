# %%
import csv
import random
import math
import operator
from sklearn.metrics import mean_squared_error

# Loading Data Set
def load_Dataset(filename, split, trainingSet=[] , testSet=[]):
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
        for x in range(len(dataset)-1):
            for y in range(24):
                dataset[x][y] = float(dataset[x][y])
            if random.random() < split:
                trainingSet.append(dataset[x])
            else:
                testSet.append(dataset[x])

# Euclidean distance algorithm for training set + test instance
# length controls the which fields to include in distance calculation

def euclidean_Distance(instance1, instance2, length):
    distance = 0
    for x in range(length):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)

# Finding the neighbors of the test instance in the training set

def get_Neighbors(trainingSet, testInstance, k):
    distances = []
    length = len(testInstance)-1
    for x in range(len(trainingSet)):
        dist = euclidean_Distance(testInstance, trainingSet[x], length)
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors
 
# Voting on all the neighbors to classify the test instance 

def get_Response(neighbors):
    Votes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][-1]
        if response in Votes:
            Votes[response] += 1
        else:
            Votes[response] = 1
    sortedVotes = sorted(Votes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]
 
# Accuracy test

def get_Accuracy(testSet, predictions):
    correct = 0
    for x in range(len(testSet)):
        if (testSet[x][-1] <predictions[x]*1.05 and testSet[x][-1] >predictions[x]*0.95) :
            correct += 1
    return (correct/float(len(testSet))) * 100.0

def main():
    # Format Date
    trainingSet=[]
    testSet=[]
    split = 0.95
    load_Dataset('finalinputs.csv', split, trainingSet, testSet)
    print ('Train set: ' + repr(len(trainingSet)))
    print ('Test set: ' + repr(len(testSet)) + '\n') 
    # generate predictions
    predictions=[]
    k = 9
    for x in range(len(testSet)):
        neighbors = get_Neighbors(trainingSet, testSet[x], k)
        result = get_Response(neighbors)
        predictions.append(result)
        print('> Predicted = $' + repr(result) + ', Actual = $' + repr(testSet[x][-1]))
        #print('> Actual = ' + repr(testSet[x][-1]) + ', Predicted = ' + repr(result))
    accuracy = get_Accuracy(testSet, predictions)
    print('Accuracy: ' + repr(accuracy))
main()
# Out:
# Train set: 11502
# Test set: 580
#
# > Predicted = $920.0, Actual = $952.0
# > Predicted = $656.0, Actual = $342.0
# > Predicted = $193.0, Actual = $249.0
# > Predicted = $1719.0, Actual = $2467.0
# > Predicted = $2677.0, Actual = $2565.0
# > Predicted = $1430.0, Actual = $1435.0
# > Predicted = $146.0, Actual = $172.0
# > Predicted = $1501.0, Actual = $984.0
# > Predicted = $553.0, Actual = $750.0
# > Predicted = $1310.0, Actual = $1131.0
# > Predicted = $3936.0, Actual = $2445.0
# > Predicted = $1583.0, Actual = $1689.0
# > Predicted = $2082.0, Actual = $1820.0
# > Predicted = $1910.0, Actual = $2026.0
# > Predicted = $746.0, Actual = $565.0
# > Predicted = $668.0, Actual = $675.0
# > Predicted = $2617.0, Actual = $2538.0
# > Predicted = $443.0, Actual = $719.0
# > Predicted = $712.0, Actual = $728.0
# > Predicted = $966.0, Actual = $930.0
# > Predicted = $967.0, Actual = $1042.0
# > Predicted = $979.0, Actual = $551.0
# > Predicted = $703.0, Actual = $1011.0
# > Predicted = $2209.0, Actual = $3543.0
# > Predicted = $1899.0, Actual = $1701.0
# > Predicted = $2710.0, Actual = $2820.0
# > Predicted = $668.0, Actual = $768.0
# > Predicted = $985.0, Actual = $805.0
# > Predicted = $580.0, Actual = $617.0
# > Predicted = $1198.0, Actual = $1603.0
# > Predicted = $2425.0, Actual = $2374.0
# > Predicted = $1334.0, Actual = $1065.0
# > Predicted = $931.0, Actual = $862.0
# > Predicted = $3643.0, Actual = $5801.0
# > Predicted = $578.0, Actual = $803.0
# > Predicted = $781.0, Actual = $1159.0
# > Predicted = $1525.0, Actual = $1496.0
# > Predicted = $806.0, Actual = $943.0
# > Predicted = $265.0, Actual = $301.0
# > Predicted = $772.0, Actual = $942.0
# > Predicted = $481.0, Actual = $666.0
# > Predicted = $1664.0, Actual = $1260.0
# > Predicted = $1528.0, Actual = $1687.0
# > Predicted = $1421.0, Actual = $1403.0
# > Predicted = $3848.0, Actual = $3554.0
# > Predicted = $1738.0, Actual = $1154.0
# > Predicted = $2654.0, Actual = $3288.0
# > Predicted = $830.0, Actual = $1018.0
# > Predicted = $730.0, Actual = $1205.0
# > Predicted = $2113.0, Actual = $2243.0
# > Predicted = $1664.0, Actual = $1196.0
# > Predicted = $1554.0, Actual = $1635.0
# > Predicted = $1227.0, Actual = $1587.0
# > Predicted = $632.0, Actual = $1013.0
# > Predicted = $519.0, Actual = $827.0
# > Predicted = $1280.0, Actual = $1578.0
# > Predicted = $258.0, Actual = $271.0
# > Predicted = $832.0, Actual = $501.0
# > Predicted = $927.0, Actual = $1030.0
# > Predicted = $1026.0, Actual = $956.0
# > Predicted = $3126.0, Actual = $2131.0
# > Predicted = $655.0, Actual = $964.0
# > Predicted = $987.0, Actual = $717.0
# > Predicted = $1458.0, Actual = $1595.0
# > Predicted = $1662.0, Actual = $939.0
# > Predicted = $1158.0, Actual = $1974.0
# > Predicted = $858.0, Actual = $1144.0
# > Predicted = $1187.0, Actual = $925.0
# > Predicted = $1879.0, Actual = $1738.0
# > Predicted = $302.0, Actual = $280.0
# > Predicted = $2261.0, Actual = $2254.0
# > Predicted = $3795.0, Actual = $2800.0
# > Predicted = $1015.0, Actual = $1158.0
# > Predicted = $2339.0, Actual = $2463.0
# > Predicted = $1283.0, Actual = $1178.0
# > Predicted = $2156.0, Actual = $2023.0
# > Predicted = $365.0, Actual = $512.0
# > Predicted = $468.0, Actual = $341.0
# > Predicted = $1430.0, Actual = $1512.0
# > Predicted = $1401.0, Actual = $1037.0
# > Predicted = $1662.0, Actual = $1725.0
# > Predicted = $2106.0, Actual = $1968.0
# > Predicted = $773.0, Actual = $1008.0
# > Predicted = $1195.0, Actual = $719.0
# > Predicted = $392.0, Actual = $436.0
# > Predicted = $820.0, Actual = $863.0
# > Predicted = $271.0, Actual = $422.0
# > Predicted = $1630.0, Actual = $1999.0
# > Predicted = $1768.0, Actual = $1036.0
# > Predicted = $2007.0, Actual = $1869.0
# > Predicted = $1084.0, Actual = $1106.0
# > Predicted = $1163.0, Actual = $852.0
# > Predicted = $1970.0, Actual = $2305.0
# > Predicted = $408.0, Actual = $411.0
# > Predicted = $2283.0, Actual = $1832.0
# > Predicted = $1893.0, Actual = $1803.0
# > Predicted = $2028.0, Actual = $1766.0
# > Predicted = $2060.0, Actual = $1598.0
# > Predicted = $569.0, Actual = $582.0
# > Predicted = $503.0, Actual = $829.0
# > Predicted = $848.0, Actual = $586.0
# > Predicted = $2625.0, Actual = $2184.0
# > Predicted = $835.0, Actual = $638.0
# > Predicted = $520.0, Actual = $337.0
# > Predicted = $1332.0, Actual = $1371.0
# > Predicted = $831.0, Actual = $1185.0
# > Predicted = $990.0, Actual = $764.0
# > Predicted = $1159.0, Actual = $1268.0
# > Predicted = $708.0, Actual = $700.0
# > Predicted = $447.0, Actual = $364.0
# > Predicted = $1099.0, Actual = $1182.0
# > Predicted = $789.0, Actual = $591.0
# > Predicted = $5698.0, Actual = $4950.0
# > Predicted = $771.0, Actual = $658.0
# > Predicted = $407.0, Actual = $497.0
# > Predicted = $794.0, Actual = $720.0
# > Predicted = $1335.0, Actual = $2144.0
# > Predicted = $1033.0, Actual = $1018.0
# > Predicted = $943.0, Actual = $1117.0
# > Predicted = $1586.0, Actual = $1439.0
# > Predicted = $425.0, Actual = $703.0
# > Predicted = $3696.0, Actual = $3728.0
# > Predicted = $4388.0, Actual = $3672.0
# > Predicted = $2407.0, Actual = $2308.0
# > Predicted = $252.0, Actual = $416.0
# > Predicted = $1122.0, Actual = $1407.0
# > Predicted = $1295.0, Actual = $1225.0
# > Predicted = $1456.0, Actual = $1279.0
# > Predicted = $5698.0, Actual = $5947.0
# > Predicted = $1220.0, Actual = $1124.0
# > Predicted = $742.0, Actual = $1026.0
# > Predicted = $648.0, Actual = $716.0
# > Predicted = $585.0, Actual = $697.0
# > Predicted = $1537.0, Actual = $2276.0
# > Predicted = $1856.0, Actual = $1895.0
# > Predicted = $800.0, Actual = $841.0
# > Predicted = $800.0, Actual = $838.0
# > Predicted = $1150.0, Actual = $1579.0
# > Predicted = $799.0, Actual = $1385.0
# > Predicted = $288.0, Actual = $415.0
# > Predicted = $1296.0, Actual = $1356.0
# > Predicted = $1087.0, Actual = $715.0
# > Predicted = $2285.0, Actual = $2297.0
# > Predicted = $675.0, Actual = $680.0
# > Predicted = $823.0, Actual = $615.0
# > Predicted = $1175.0, Actual = $1115.0
# > Predicted = $2219.0, Actual = $3511.0
# > Predicted = $850.0, Actual = $569.0
# > Predicted = $1764.0, Actual = $985.0
# > Predicted = $1428.0, Actual = $1430.0
# > Predicted = $1615.0, Actual = $1721.0
# > Predicted = $655.0, Actual = $557.0
# > Predicted = $1298.0, Actual = $1548.0
# > Predicted = $496.0, Actual = $470.0
# > Predicted = $308.0, Actual = $231.0
# > Predicted = $2201.0, Actual = $1907.0
# > Predicted = $937.0, Actual = $854.0
# > Predicted = $1096.0, Actual = $1055.0
# > Predicted = $859.0, Actual = $860.0
# > Predicted = $1189.0, Actual = $1343.0
# > Predicted = $177.0, Actual = $265.0
# > Predicted = $1484.0, Actual = $1365.0
# > Predicted = $1480.0, Actual = $1318.0
# > Predicted = $735.0, Actual = $546.0
# > Predicted = $451.0, Actual = $441.0
# > Predicted = $2131.0, Actual = $2062.0
# > Predicted = $860.0, Actual = $841.0
# > Predicted = $1082.0, Actual = $1088.0
# > Predicted = $773.0, Actual = $975.0
# > Predicted = $599.0, Actual = $673.0
# > Predicted = $2156.0, Actual = $1860.0
# > Predicted = $1742.0, Actual = $1690.0
# > Predicted = $1924.0, Actual = $2218.0
# > Predicted = $1066.0, Actual = $779.0
# > Predicted = $2522.0, Actual = $2264.0
# > Predicted = $1118.0, Actual = $1291.0
# > Predicted = $441.0, Actual = $620.0
# > Predicted = $2759.0, Actual = $2846.0
# > Predicted = $2286.0, Actual = $2807.0
# > Predicted = $1589.0, Actual = $1538.0
# > Predicted = $1051.0, Actual = $1234.0
# > Predicted = $1692.0, Actual = $1669.0
# > Predicted = $327.0, Actual = $909.0
# > Predicted = $797.0, Actual = $528.0
# > Predicted = $2375.0, Actual = $2735.0
# > Predicted = $1176.0, Actual = $1520.0
# > Predicted = $3846.0, Actual = $2021.0
# > Predicted = $719.0, Actual = $703.0
# > Predicted = $10740.0, Actual = $7701.0
# > Predicted = $1150.0, Actual = $1333.0
# > Predicted = $424.0, Actual = $409.0
# > Predicted = $630.0, Actual = $623.0
# > Predicted = $1452.0, Actual = $1409.0
# > Predicted = $825.0, Actual = $1873.0
# > Predicted = $750.0, Actual = $997.0
# > Predicted = $1908.0, Actual = $2616.0
# > Predicted = $1800.0, Actual = $1773.0
# > Predicted = $3067.0, Actual = $1981.0
# > Predicted = $1315.0, Actual = $1614.0
# > Predicted = $322.0, Actual = $361.0
# > Predicted = $1020.0, Actual = $965.0
# > Predicted = $1686.0, Actual = $2030.0
# > Predicted = $1122.0, Actual = $701.0
# > Predicted = $2209.0, Actual = $2108.0
# > Predicted = $1753.0, Actual = $2150.0
# > Predicted = $969.0, Actual = $1050.0
# > Predicted = $862.0, Actual = $1073.0
# > Predicted = $862.0, Actual = $1176.0
# > Predicted = $3454.0, Actual = $4296.0
# > Predicted = $2932.0, Actual = $3177.0
# > Predicted = $2356.0, Actual = $1857.0
# > Predicted = $599.0, Actual = $665.0
# > Predicted = $565.0, Actual = $451.0
# > Predicted = $2051.0, Actual = $4343.0
# > Predicted = $1221.0, Actual = $1422.0
# > Predicted = $1371.0, Actual = $1317.0
# > Predicted = $1630.0, Actual = $1710.0
# > Predicted = $911.0, Actual = $929.0
# > Predicted = $941.0, Actual = $796.0
# > Predicted = $2765.0, Actual = $3240.0
# > Predicted = $854.0, Actual = $865.0
# > Predicted = $893.0, Actual = $964.0
# > Predicted = $1594.0, Actual = $1121.0
# > Predicted = $2338.0, Actual = $2516.0
# > Predicted = $887.0, Actual = $797.0
# > Predicted = $1613.0, Actual = $3391.0
# > Predicted = $5371.0, Actual = $3304.0
# > Predicted = $1480.0, Actual = $1297.0
# > Predicted = $1675.0, Actual = $1748.0
# > Predicted = $519.0, Actual = $361.0
# > Predicted = $606.0, Actual = $629.0
# > Predicted = $455.0, Actual = $509.0
# > Predicted = $1203.0, Actual = $1437.0
# > Predicted = $1701.0, Actual = $1743.0
# > Predicted = $969.0, Actual = $1062.0
# > Predicted = $1175.0, Actual = $1203.0
# > Predicted = $674.0, Actual = $896.0
# > Predicted = $1906.0, Actual = $1221.0
# > Predicted = $1323.0, Actual = $1374.0
# > Predicted = $832.0, Actual = $458.0
# > Predicted = $496.0, Actual = $468.0
# > Predicted = $1613.0, Actual = $1956.0
# > Predicted = $1296.0, Actual = $1367.0
# > Predicted = $893.0, Actual = $1173.0
# > Predicted = $617.0, Actual = $844.0
# > Predicted = $378.0, Actual = $443.0
# > Predicted = $1246.0, Actual = $1425.0
# > Predicted = $1462.0, Actual = $1415.0
# > Predicted = $936.0, Actual = $582.0
# > Predicted = $1177.0, Actual = $1626.0
# > Predicted = $985.0, Actual = $991.0
# > Predicted = $1764.0, Actual = $1446.0
# > Predicted = $536.0, Actual = $366.0
# > Predicted = $808.0, Actual = $1055.0
# > Predicted = $1207.0, Actual = $1510.0
# > Predicted = $2224.0, Actual = $1707.0
# > Predicted = $562.0, Actual = $592.0
# > Predicted = $773.0, Actual = $726.0
# > Predicted = $1896.0, Actual = $1872.0
# > Predicted = $1820.0, Actual = $1604.0
# > Predicted = $708.0, Actual = $573.0
# > Predicted = $442.0, Actual = $562.0
# > Predicted = $1031.0, Actual = $1082.0
# > Predicted = $764.0, Actual = $1159.0
# > Predicted = $1056.0, Actual = $1044.0
# > Predicted = $1520.0, Actual = $886.0
# > Predicted = $609.0, Actual = $564.0
# > Predicted = $615.0, Actual = $743.0
# > Predicted = $3454.0, Actual = $1825.0
# > Predicted = $1913.0, Actual = $1688.0
# > Predicted = $2172.0, Actual = $1455.0
# > Predicted = $506.0, Actual = $918.0
# > Predicted = $1024.0, Actual = $1473.0
# > Predicted = $1441.0, Actual = $983.0
# > Predicted = $307.0, Actual = $294.0
# > Predicted = $1137.0, Actual = $1875.0
# > Predicted = $1045.0, Actual = $843.0
# > Predicted = $881.0, Actual = $877.0
# > Predicted = $534.0, Actual = $394.0
# > Predicted = $705.0, Actual = $833.0
# > Predicted = $1262.0, Actual = $1287.0
# > Predicted = $400.0, Actual = $402.0
# > Predicted = $2619.0, Actual = $2416.0
# > Predicted = $2968.0, Actual = $1758.0
# > Predicted = $2522.0, Actual = $1515.0
# > Predicted = $1850.0, Actual = $1220.0
# > Predicted = $3986.0, Actual = $3637.0
# > Predicted = $896.0, Actual = $1096.0
# > Predicted = $817.0, Actual = $785.0
# > Predicted = $1660.0, Actual = $1836.0
# > Predicted = $685.0, Actual = $482.0
# > Predicted = $1124.0, Actual = $1038.0
# > Predicted = $778.0, Actual = $642.0
# > Predicted = $826.0, Actual = $844.0
# > Predicted = $1603.0, Actual = $1547.0
# > Predicted = $937.0, Actual = $1328.0
# > Predicted = $625.0, Actual = $719.0
# > Predicted = $1116.0, Actual = $798.0
# > Predicted = $1383.0, Actual = $2143.0
# > Predicted = $2282.0, Actual = $2394.0
# > Predicted = $206.0, Actual = $301.0
# > Predicted = $1589.0, Actual = $1330.0
# > Predicted = $733.0, Actual = $1084.0
# > Predicted = $813.0, Actual = $1085.0
# > Predicted = $1332.0, Actual = $1598.0
# > Predicted = $1328.0, Actual = $1268.0
# > Predicted = $1226.0, Actual = $1291.0
# > Predicted = $2520.0, Actual = $2792.0
# > Predicted = $1012.0, Actual = $586.0
# > Predicted = $1412.0, Actual = $1538.0
# > Predicted = $749.0, Actual = $544.0
# > Predicted = $1323.0, Actual = $1173.0
# > Predicted = $1797.0, Actual = $2145.0
# > Predicted = $1288.0, Actual = $1080.0
# > Predicted = $2465.0, Actual = $1876.0
# > Predicted = $2917.0, Actual = $3167.0
# > Predicted = $1397.0, Actual = $1496.0
# > Predicted = $1366.0, Actual = $1292.0
# > Predicted = $650.0, Actual = $591.0
# > Predicted = $3714.0, Actual = $3787.0
# > Predicted = $575.0, Actual = $555.0
# > Predicted = $371.0, Actual = $311.0
# > Predicted = $1800.0, Actual = $1587.0
# > Predicted = $624.0, Actual = $641.0
# > Predicted = $706.0, Actual = $1121.0
# > Predicted = $1072.0, Actual = $1116.0
# > Predicted = $965.0, Actual = $1028.0
# > Predicted = $932.0, Actual = $664.0
# > Predicted = $609.0, Actual = $623.0
# > Predicted = $248.0, Actual = $293.0
# > Predicted = $266.0, Actual = $295.0
# > Predicted = $649.0, Actual = $1146.0
# > Predicted = $1415.0, Actual = $1229.0
# > Predicted = $425.0, Actual = $507.0
# > Predicted = $646.0, Actual = $647.0
# > Predicted = $2700.0, Actual = $2507.0
# > Predicted = $2926.0, Actual = $2945.0
# > Predicted = $2184.0, Actual = $1732.0
# > Predicted = $1001.0, Actual = $946.0
# > Predicted = $210.0, Actual = $196.0
# > Predicted = $1659.0, Actual = $1598.0
# > Predicted = $3237.0, Actual = $4224.0
# > Predicted = $1716.0, Actual = $1963.0
# > Predicted = $336.0, Actual = $366.0
# > Predicted = $260.0, Actual = $179.0
# > Predicted = $1161.0, Actual = $1046.0
# > Predicted = $514.0, Actual = $649.0
# > Predicted = $1769.0, Actual = $1808.0
# > Predicted = $448.0, Actual = $593.0
# > Predicted = $1416.0, Actual = $1402.0
# > Predicted = $348.0, Actual = $177.0
# > Predicted = $764.0, Actual = $722.0
# > Predicted = $1588.0, Actual = $2043.0
# > Predicted = $1206.0, Actual = $1329.0
# > Predicted = $865.0, Actual = $953.0
# > Predicted = $534.0, Actual = $822.0
# > Predicted = $1712.0, Actual = $2030.0
# > Predicted = $627.0, Actual = $694.0
# > Predicted = $1426.0, Actual = $1387.0
# > Predicted = $256.0, Actual = $288.0
# > Predicted = $1377.0, Actual = $1297.0
# > Predicted = $533.0, Actual = $370.0
# > Predicted = $828.0, Actual = $876.0
# > Predicted = $1182.0, Actual = $1249.0
# > Predicted = $2838.0, Actual = $2958.0
# > Predicted = $1455.0, Actual = $1383.0
# > Predicted = $902.0, Actual = $773.0
# > Predicted = $5263.0, Actual = $5192.0
# > Predicted = $812.0, Actual = $1302.0
# > Predicted = $1002.0, Actual = $805.0
# > Predicted = $656.0, Actual = $661.0
# > Predicted = $2803.0, Actual = $1904.0
# > Predicted = $773.0, Actual = $926.0
# > Predicted = $2607.0, Actual = $2576.0
# > Predicted = $653.0, Actual = $1466.0
# > Predicted = $2030.0, Actual = $2013.0
# > Predicted = $1752.0, Actual = $1419.0
# > Predicted = $1967.0, Actual = $1784.0
# > Predicted = $862.0, Actual = $1560.0
# > Predicted = $1929.0, Actual = $1975.0
# > Predicted = $318.0, Actual = $884.0
# > Predicted = $510.0, Actual = $505.0
# > Predicted = $1477.0, Actual = $1230.0
# > Predicted = $1635.0, Actual = $1781.0
# > Predicted = $1270.0, Actual = $1510.0
# > Predicted = $679.0, Actual = $893.0
# > Predicted = $1546.0, Actual = $1443.0
# > Predicted = $1442.0, Actual = $1869.0
# > Predicted = $1864.0, Actual = $1759.0
# > Predicted = $2154.0, Actual = $1742.0
# > Predicted = $1349.0, Actual = $1531.0
# > Predicted = $500.0, Actual = $356.0
# > Predicted = $1110.0, Actual = $863.0
# > Predicted = $411.0, Actual = $646.0
# > Predicted = $1664.0, Actual = $785.0
# > Predicted = $2784.0, Actual = $2946.0
# > Predicted = $1072.0, Actual = $1041.0
# > Predicted = $2086.0, Actual = $2293.0
# > Predicted = $1868.0, Actual = $1887.0
# > Predicted = $1487.0, Actual = $1847.0
# > Predicted = $590.0, Actual = $550.0
# > Predicted = $1871.0, Actual = $1745.0
# > Predicted = $1011.0, Actual = $1163.0
# > Predicted = $905.0, Actual = $882.0
# > Predicted = $936.0, Actual = $1618.0
# > Predicted = $442.0, Actual = $361.0
# > Predicted = $626.0, Actual = $392.0
# > Predicted = $1727.0, Actual = $2415.0
# > Predicted = $1692.0, Actual = $1374.0
# > Predicted = $1469.0, Actual = $1426.0
# > Predicted = $860.0, Actual = $866.0
# > Predicted = $1777.0, Actual = $1492.0
# > Predicted = $265.0, Actual = $239.0
# > Predicted = $851.0, Actual = $812.0
# > Predicted = $2462.0, Actual = $1703.0
# > Predicted = $855.0, Actual = $959.0
# > Predicted = $838.0, Actual = $688.0
# > Predicted = $2742.0, Actual = $2788.0
# > Predicted = $1022.0, Actual = $1340.0
# > Predicted = $1250.0, Actual = $2036.0
# > Predicted = $1054.0, Actual = $835.0
# > Predicted = $823.0, Actual = $856.0
# > Predicted = $1587.0, Actual = $1870.0
# > Predicted = $1746.0, Actual = $1293.0
# > Predicted = $643.0, Actual = $501.0
# > Predicted = $962.0, Actual = $660.0
# > Predicted = $914.0, Actual = $908.0
# > Predicted = $1155.0, Actual = $1157.0
# > Predicted = $3396.0, Actual = $1747.0
# > Predicted = $749.0, Actual = $720.0
# > Predicted = $2108.0, Actual = $2062.0
# > Predicted = $1510.0, Actual = $697.0
# > Predicted = $740.0, Actual = $783.0
# > Predicted = $2202.0, Actual = $2265.0
# > Predicted = $1216.0, Actual = $1225.0
# > Predicted = $1340.0, Actual = $1542.0
# > Predicted = $292.0, Actual = $528.0
# > Predicted = $614.0, Actual = $673.0
# > Predicted = $1095.0, Actual = $1244.0
# > Predicted = $2086.0, Actual = $2103.0
# > Predicted = $1793.0, Actual = $1534.0
# > Predicted = $756.0, Actual = $745.0
# > Predicted = $1648.0, Actual = $1685.0
# > Predicted = $1190.0, Actual = $991.0
# > Predicted = $420.0, Actual = $459.0
# > Predicted = $1354.0, Actual = $1121.0
# > Predicted = $596.0, Actual = $722.0
# > Predicted = $1621.0, Actual = $1570.0
# > Predicted = $1332.0, Actual = $2242.0
# > Predicted = $1551.0, Actual = $1354.0
# > Predicted = $2065.0, Actual = $2200.0
# > Predicted = $904.0, Actual = $1021.0
# > Predicted = $657.0, Actual = $788.0
# > Predicted = $1353.0, Actual = $815.0
# > Predicted = $2405.0, Actual = $2611.0
# > Predicted = $1452.0, Actual = $1432.0
# > Predicted = $426.0, Actual = $596.0
# > Predicted = $1380.0, Actual = $1160.0
# > Predicted = $2132.0, Actual = $2952.0
# > Predicted = $1379.0, Actual = $2099.0
# > Predicted = $1752.0, Actual = $2742.0
# > Predicted = $1738.0, Actual = $2283.0
# > Predicted = $1072.0, Actual = $1186.0
# > Predicted = $2390.0, Actual = $1673.0
# > Predicted = $883.0, Actual = $823.0
# > Predicted = $510.0, Actual = $437.0
# > Predicted = $830.0, Actual = $719.0
# > Predicted = $579.0, Actual = $551.0
# > Predicted = $960.0, Actual = $910.0
# > Predicted = $1669.0, Actual = $2461.0
# > Predicted = $1328.0, Actual = $1342.0
# > Predicted = $2665.0, Actual = $2870.0
# > Predicted = $872.0, Actual = $998.0
# > Predicted = $1167.0, Actual = $865.0
# > Predicted = $336.0, Actual = $321.0
# > Predicted = $1856.0, Actual = $1173.0
# > Predicted = $1793.0, Actual = $2178.0
# > Predicted = $796.0, Actual = $895.0
# > Predicted = $1082.0, Actual = $996.0
# > Predicted = $1068.0, Actual = $717.0
# > Predicted = $331.0, Actual = $400.0
# > Predicted = $2059.0, Actual = $1405.0
# > Predicted = $1573.0, Actual = $1281.0
# > Predicted = $1381.0, Actual = $1820.0
# > Predicted = $1613.0, Actual = $1386.0
# > Predicted = $1200.0, Actual = $1041.0
# > Predicted = $1762.0, Actual = $1768.0
# > Predicted = $1122.0, Actual = $1086.0
# > Predicted = $1586.0, Actual = $1211.0
# > Predicted = $1960.0, Actual = $2607.0
# > Predicted = $1228.0, Actual = $1637.0
# > Predicted = $1103.0, Actual = $1285.0
# > Predicted = $735.0, Actual = $1044.0
# > Predicted = $2821.0, Actual = $3090.0
# > Predicted = $591.0, Actual = $602.0
# > Predicted = $2061.0, Actual = $2239.0
# > Predicted = $1078.0, Actual = $960.0
# > Predicted = $557.0, Actual = $522.0
# > Predicted = $2450.0, Actual = $1859.0
# > Predicted = $520.0, Actual = $625.0
# > Predicted = $1477.0, Actual = $1189.0
# > Predicted = $259.0, Actual = $121.0
# > Predicted = $423.0, Actual = $290.0
# > Predicted = $1190.0, Actual = $1793.0
# > Predicted = $1722.0, Actual = $1695.0
# > Predicted = $1096.0, Actual = $1607.0
# > Predicted = $1000.0, Actual = $1207.0
# > Predicted = $3228.0, Actual = $1981.0
# > Predicted = $1931.0, Actual = $1487.0
# > Predicted = $683.0, Actual = $1439.0
# > Predicted = $1427.0, Actual = $1391.0
# > Predicted = $191.0, Actual = $193.0
# > Predicted = $900.0, Actual = $872.0
# > Predicted = $391.0, Actual = $424.0
# > Predicted = $1964.0, Actual = $2865.0
# > Predicted = $1178.0, Actual = $664.0
# > Predicted = $1147.0, Actual = $1163.0
# > Predicted = $96.0, Actual = $195.0
# > Predicted = $896.0, Actual = $884.0
# > Predicted = $566.0, Actual = $434.0
# > Predicted = $4476.0, Actual = $3899.0
# > Predicted = $629.0, Actual = $686.0
# > Predicted = $2087.0, Actual = $3216.0
# > Predicted = $2565.0, Actual = $2442.0
# > Predicted = $767.0, Actual = $1126.0
# > Predicted = $1618.0, Actual = $1781.0
# > Predicted = $1452.0, Actual = $1667.0
# > Predicted = $621.0, Actual = $613.0
# > Predicted = $888.0, Actual = $816.0
# > Predicted = $2327.0, Actual = $2253.0
# > Predicted = $1636.0, Actual = $1640.0
# > Predicted = $466.0, Actual = $671.0
# > Predicted = $856.0, Actual = $716.0
# > Predicted = $3838.0, Actual = $3497.0
# > Predicted = $772.0, Actual = $757.0
# > Predicted = $735.0, Actual = $457.0
# > Predicted = $743.0, Actual = $941.0
# > Predicted = $487.0, Actual = $623.0
# > Predicted = $1365.0, Actual = $1257.0
# > Predicted = $1676.0, Actual = $1448.0
# > Predicted = $308.0, Actual = $289.0
# > Predicted = $994.0, Actual = $426.0
# > Predicted = $1462.0, Actual = $1870.0
# > Predicted = $1199.0, Actual = $1412.0
# > Predicted = $411.0, Actual = $438.0
# > Predicted = $1290.0, Actual = $1036.0
# > Predicted = $3108.0, Actual = $2894.0
# > Predicted = $340.0, Actual = $249.0
# > Predicted = $3098.0, Actual = $2559.0
# > Predicted = $394.0, Actual = $370.0
# > Predicted = $0.0, Actual = $140.0
# > Predicted = $1832.0, Actual = $1828.0
# > Predicted = $672.0, Actual = $651.0
# > Predicted = $1097.0, Actual = $1174.0
# > Predicted = $562.0, Actual = $808.0
# > Predicted = $759.0, Actual = $686.0
# > Predicted = $1236.0, Actual = $974.0
# > Predicted = $4314.0, Actual = $4295.0
# > Predicted = $324.0, Actual = $277.0
# > Predicted = $751.0, Actual = $893.0
# > Predicted = $2561.0, Actual = $2757.0
# > Predicted = $2262.0, Actual = $1962.0
# > Predicted = $2437.0, Actual = $2329.0
# > Predicted = $1021.0, Actual = $1205.0
# > Predicted = $2688.0, Actual = $2626.0
# > Predicted = $1194.0, Actual = $803.0
# > Predicted = $950.0, Actual = $943.0
# > Predicted = $351.0, Actual = $323.0
# > Predicted = $2139.0, Actual = $1765.0
# > Predicted = $626.0, Actual = $1154.0
# > Predicted = $1319.0, Actual = $755.0
# > Predicted = $969.0, Actual = $969.0
# > Predicted = $1647.0, Actual = $813.0
# > Predicted = $2154.0, Actual = $2096.0
# > Predicted = $512.0, Actual = $491.0
# > Predicted = $3511.0, Actual = $2982.0
# > Predicted = $1740.0, Actual = $1698.0
# > Predicted = $1709.0, Actual = $1496.0
# > Predicted = $1338.0, Actual = $1325.0
# > Predicted = $490.0, Actual = $454.0
# Accuracy: 68.44827586206897
