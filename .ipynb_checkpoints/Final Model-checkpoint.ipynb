# %%
import csv
import random
import math
import operator
from sklearn.metrics import mean_squared_error

# Loading Data Set
def load_Dataset(filename, split, trainingSet=[] , testSet=[]):
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
        for x in range(len(dataset)-1):
            for y in range(24):
                dataset[x][y] = float(dataset[x][y])
            if random.random() < split:
                trainingSet.append(dataset[x])
            else:
                testSet.append(dataset[x])

# Euclidean distance algorithm for training set + test instance
# length controls the which fields to include in distance calculation

def euclidean_Distance(instance1, instance2, length):
    distance = 0
    for x in range(length):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)

# Finding the neighbors of the test instance in the training set

def get_Neighbors(trainingSet, testInstance, k):
    distances = []
    length = len(testInstance)-1
    for x in range(len(trainingSet)):
        dist = euclidean_Distance(testInstance, trainingSet[x], length)
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors
 
# Voting on all the neighbors to classify the test instance 

def get_Response(neighbors):
    Votes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][-1]
        if response in Votes:
            Votes[response] += 1
        else:
            Votes[response] = 1
    sortedVotes = sorted(Votes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]
 
# Accuracy test

def get_Accuracy(testSet, predictions):
    correct = 0
    for x in range(len(testSet)):
        if testSet[x][-1] == predictions[x]:
            correct += 1
    return (correct/float(len(testSet))) * 100.0

def main():
    # Format Date
    trainingSet=[]
    testSet=[]
    split = 0.95
    load_Dataset('finalinputs.csv', split, trainingSet, testSet)
    print ('Train set: ' + repr(len(trainingSet)))
    print ('Test set: ' + repr(len(testSet)) + '\n') 
    # generate predictions
    predictions=[]
    k = 9
    for x in range(len(testSet)):
        neighbors = get_Neighbors(trainingSet, testSet[x], k)
        result = get_Response(neighbors)
        predictions.append(result)
        print('> Predicted = $' + repr(result) + ', Actual = $' + repr(testSet[x][-1]))
        #print('> Actual = ' + repr(testSet[x][-1]) + ', Predicted = ' + repr(result))
    accuracy = get_Accuracy(testSet, predictions)
    print('Accuracy: ' + repr(accuracy))
main()
# Out:
# Train set: 11481
# Test set: 601
#
# > Predicted = $865.0, Actual = $943.0
# > Predicted = $1845.0, Actual = $2046.0
# > Predicted = $917.0, Actual = $1342.0
# > Predicted = $1241.0, Actual = $1161.0
# > Predicted = $858.0, Actual = $1281.0
# > Predicted = $293.0, Actual = $535.0
# > Predicted = $995.0, Actual = $964.0
# > Predicted = $952.0, Actual = $920.0
# > Predicted = $966.0, Actual = $863.0
# > Predicted = $655.0, Actual = $424.0
# > Predicted = $1115.0, Actual = $1666.0
# > Predicted = $915.0, Actual = $904.0
# > Predicted = $760.0, Actual = $758.0
# > Predicted = $2209.0, Actual = $3543.0
# > Predicted = $1522.0, Actual = $1422.0
# > Predicted = $327.0, Actual = $995.0
# > Predicted = $799.0, Actual = $845.0
# > Predicted = $2897.0, Actual = $2901.0
# > Predicted = $1744.0, Actual = $1215.0
# > Predicted = $1416.0, Actual = $1249.0
# > Predicted = $2450.0, Actual = $1205.0
# > Predicted = $562.0, Actual = $570.0
# > Predicted = $600.0, Actual = $590.0
# > Predicted = $580.0, Actual = $617.0
# > Predicted = $838.0, Actual = $800.0
# > Predicted = $512.0, Actual = $395.0
# > Predicted = $704.0, Actual = $559.0
# > Predicted = $893.0, Actual = $692.0
# > Predicted = $1668.0, Actual = $1555.0
# > Predicted = $684.0, Actual = $1059.0
# > Predicted = $216.0, Actual = $289.0
# > Predicted = $997.0, Actual = $896.0
# > Predicted = $1329.0, Actual = $1309.0
# > Predicted = $206.0, Actual = $228.0
# > Predicted = $898.0, Actual = $1217.0
# > Predicted = $697.0, Actual = $378.0
# > Predicted = $1621.0, Actual = $2590.0
# > Predicted = $382.0, Actual = $442.0
# > Predicted = $405.0, Actual = $352.0
# > Predicted = $2604.0, Actual = $1747.0
# > Predicted = $2467.0, Actual = $1638.0
# > Predicted = $439.0, Actual = $533.0
# > Predicted = $2572.0, Actual = $1873.0
# > Predicted = $1560.0, Actual = $1283.0
# > Predicted = $1509.0, Actual = $1558.0
# > Predicted = $1985.0, Actual = $1185.0
# > Predicted = $1085.0, Actual = $813.0
# > Predicted = $594.0, Actual = $487.0
# > Predicted = $976.0, Actual = $999.0
# > Predicted = $784.0, Actual = $451.0
# > Predicted = $683.0, Actual = $931.0
# > Predicted = $403.0, Actual = $380.0
# > Predicted = $1017.0, Actual = $931.0
# > Predicted = $75.0, Actual = $57.0
# > Predicted = $1554.0, Actual = $1635.0
# > Predicted = $276.0, Actual = $576.0
# > Predicted = $1392.0, Actual = $1059.0
# > Predicted = $698.0, Actual = $446.0
# > Predicted = $1872.0, Actual = $3209.0
# > Predicted = $1019.0, Actual = $1077.0
# > Predicted = $746.0, Actual = $814.0
# > Predicted = $1318.0, Actual = $1358.0
# > Predicted = $1508.0, Actual = $2548.0
# > Predicted = $884.0, Actual = $936.0
# > Predicted = $2911.0, Actual = $1846.0
# > Predicted = $857.0, Actual = $1542.0
# > Predicted = $1540.0, Actual = $2203.0
# > Predicted = $2432.0, Actual = $3420.0
# > Predicted = $910.0, Actual = $1191.0
# > Predicted = $1696.0, Actual = $1338.0
# > Predicted = $1517.0, Actual = $1062.0
# > Predicted = $783.0, Actual = $739.0
# > Predicted = $1740.0, Actual = $1774.0
# > Predicted = $2051.0, Actual = $1984.0
# > Predicted = $1051.0, Actual = $968.0
# > Predicted = $639.0, Actual = $603.0
# > Predicted = $3126.0, Actual = $2131.0
# > Predicted = $1529.0, Actual = $1262.0
# > Predicted = $1458.0, Actual = $1595.0
# > Predicted = $929.0, Actual = $939.0
# > Predicted = $3670.0, Actual = $3813.0
# > Predicted = $621.0, Actual = $1194.0
# > Predicted = $630.0, Actual = $591.0
# > Predicted = $642.0, Actual = $533.0
# > Predicted = $496.0, Actual = $371.0
# > Predicted = $1012.0, Actual = $1099.0
# > Predicted = $365.0, Actual = $512.0
# > Predicted = $3162.0, Actual = $2117.0
# > Predicted = $2178.0, Actual = $2246.0
# > Predicted = $1249.0, Actual = $826.0
# > Predicted = $1157.0, Actual = $2302.0
# > Predicted = $3369.0, Actual = $4559.0
# > Predicted = $646.0, Actual = $568.0
# > Predicted = $820.0, Actual = $863.0
# > Predicted = $719.0, Actual = $451.0
# > Predicted = $809.0, Actual = $899.0
# > Predicted = $4422.0, Actual = $7482.0
# > Predicted = $254.0, Actual = $202.0
# > Predicted = $1067.0, Actual = $1169.0
# > Predicted = $1416.0, Actual = $1364.0
# > Predicted = $1457.0, Actual = $1721.0
# > Predicted = $662.0, Actual = $623.0
# > Predicted = $612.0, Actual = $459.0
# > Predicted = $646.0, Actual = $423.0
# > Predicted = $900.0, Actual = $1033.0
# > Predicted = $1071.0, Actual = $1099.0
# > Predicted = $1352.0, Actual = $872.0
# > Predicted = $2223.0, Actual = $1416.0
# > Predicted = $3248.0, Actual = $4379.0
# > Predicted = $1012.0, Actual = $1092.0
# > Predicted = $667.0, Actual = $556.0
# > Predicted = $1092.0, Actual = $1065.0
# > Predicted = $1548.0, Actual = $1582.0
# > Predicted = $972.0, Actual = $755.0
# > Predicted = $123.0, Actual = $0.0
# > Predicted = $1430.0, Actual = $1428.0
# > Predicted = $2341.0, Actual = $2793.0
# > Predicted = $1598.0, Actual = $2093.0
# > Predicted = $1186.0, Actual = $1072.0
# > Predicted = $2328.0, Actual = $2236.0
# > Predicted = $457.0, Actual = $619.0
# > Predicted = $2253.0, Actual = $2144.0
# > Predicted = $921.0, Actual = $856.0
# > Predicted = $2001.0, Actual = $1923.0
# > Predicted = $674.0, Actual = $684.0
# > Predicted = $2115.0, Actual = $1553.0
# > Predicted = $921.0, Actual = $827.0
# > Predicted = $846.0, Actual = $653.0
# > Predicted = $1856.0, Actual = $2483.0
# > Predicted = $3787.0, Actual = $3714.0
# > Predicted = $1145.0, Actual = $1189.0
# > Predicted = $2854.0, Actual = $1814.0
# > Predicted = $1456.0, Actual = $1505.0
# > Predicted = $1127.0, Actual = $1456.0
# > Predicted = $843.0, Actual = $860.0
# > Predicted = $838.0, Actual = $898.0
# > Predicted = $1779.0, Actual = $1394.0
# > Predicted = $813.0, Actual = $602.0
# > Predicted = $704.0, Actual = $546.0
# > Predicted = $723.0, Actual = $953.0
# > Predicted = $1367.0, Actual = $1236.0
# > Predicted = $529.0, Actual = $516.0
# > Predicted = $317.0, Actual = $254.0
# > Predicted = $1935.0, Actual = $1955.0
# > Predicted = $986.0, Actual = $1114.0
# > Predicted = $1285.0, Actual = $1449.0
# > Predicted = $1297.0, Actual = $1206.0
# > Predicted = $1341.0, Actual = $1507.0
# > Predicted = $1522.0, Actual = $1324.0
# > Predicted = $1161.0, Actual = $1367.0
# > Predicted = $469.0, Actual = $420.0
# > Predicted = $436.0, Actual = $392.0
# > Predicted = $1557.0, Actual = $1266.0
# > Predicted = $1119.0, Actual = $1249.0
# > Predicted = $990.0, Actual = $911.0
# > Predicted = $454.0, Actual = $296.0
# > Predicted = $1023.0, Actual = $887.0
# > Predicted = $812.0, Actual = $535.0
# > Predicted = $1359.0, Actual = $1577.0
# > Predicted = $1520.0, Actual = $1686.0
# > Predicted = $370.0, Actual = $293.0
# > Predicted = $1311.0, Actual = $1240.0
# > Predicted = $1705.0, Actual = $1619.0
# > Predicted = $841.0, Actual = $837.0
# > Predicted = $1522.0, Actual = $1212.0
# > Predicted = $1295.0, Actual = $1086.0
# > Predicted = $1015.0, Actual = $992.0
# > Predicted = $434.0, Actual = $327.0
# > Predicted = $2820.0, Actual = $2329.0
# > Predicted = $2100.0, Actual = $1683.0
# > Predicted = $1932.0, Actual = $1652.0
# > Predicted = $502.0, Actual = $565.0
# > Predicted = $1615.0, Actual = $1412.0
# > Predicted = $937.0, Actual = $854.0
# > Predicted = $2230.0, Actual = $1800.0
# > Predicted = $299.0, Actual = $302.0
# > Predicted = $1895.0, Actual = $1433.0
# > Predicted = $1615.0, Actual = $1706.0
# > Predicted = $1623.0, Actual = $2005.0
# > Predicted = $1667.0, Actual = $1478.0
# > Predicted = $1272.0, Actual = $1237.0
# > Predicted = $714.0, Actual = $703.0
# > Predicted = $579.0, Actual = $445.0
# > Predicted = $2202.0, Actual = $2153.0
# > Predicted = $1432.0, Actual = $1250.0
# > Predicted = $1820.0, Actual = $1658.0
# > Predicted = $487.0, Actual = $634.0
# > Predicted = $1327.0, Actual = $1956.0
# > Predicted = $1548.0, Actual = $1546.0
# > Predicted = $2574.0, Actual = $3324.0
# > Predicted = $2251.0, Actual = $1487.0
# > Predicted = $886.0, Actual = $994.0
# > Predicted = $198.0, Actual = $217.0
# > Predicted = $2183.0, Actual = $1738.0
# > Predicted = $3669.0, Actual = $3764.0
# > Predicted = $1410.0, Actual = $2123.0
# > Predicted = $2301.0, Actual = $2363.0
# > Predicted = $599.0, Actual = $618.0
# > Predicted = $719.0, Actual = $703.0
# > Predicted = $6524.0, Actual = $14580.0
# > Predicted = $563.0, Actual = $565.0
# > Predicted = $1037.0, Actual = $1432.0
# > Predicted = $4295.0, Actual = $4314.0
# > Predicted = $945.0, Actual = $1022.0
# > Predicted = $1229.0, Actual = $774.0
# > Predicted = $884.0, Actual = $846.0
# > Predicted = $406.0, Actual = $292.0
# > Predicted = $962.0, Actual = $1097.0
# > Predicted = $1611.0, Actual = $1059.0
# > Predicted = $2408.0, Actual = $1783.0
# > Predicted = $306.0, Actual = $300.0
# > Predicted = $1311.0, Actual = $890.0
# > Predicted = $179.0, Actual = $854.0
# > Predicted = $2516.0, Actual = $4619.0
# > Predicted = $3013.0, Actual = $3745.0
# > Predicted = $1408.0, Actual = $1650.0
# > Predicted = $511.0, Actual = $567.0
# > Predicted = $529.0, Actual = $640.0
# > Predicted = $790.0, Actual = $729.0
# > Predicted = $624.0, Actual = $1020.0
# > Predicted = $2417.0, Actual = $2504.0
# > Predicted = $1007.0, Actual = $1148.0
# > Predicted = $1244.0, Actual = $1981.0
# > Predicted = $2018.0, Actual = $1068.0
# > Predicted = $533.0, Actual = $824.0
# > Predicted = $685.0, Actual = $722.0
# > Predicted = $463.0, Actual = $542.0
# > Predicted = $2607.0, Actual = $2804.0
# > Predicted = $2099.0, Actual = $2414.0
# > Predicted = $1431.0, Actual = $1500.0
# > Predicted = $985.0, Actual = $954.0
# > Predicted = $4296.0, Actual = $3202.0
# > Predicted = $1020.0, Actual = $1003.0
# > Predicted = $933.0, Actual = $1137.0
# > Predicted = $1668.0, Actual = $1057.0
# > Predicted = $1042.0, Actual = $1834.0
# > Predicted = $3124.0, Actual = $2633.0
# > Predicted = $3106.0, Actual = $3104.0
# > Predicted = $370.0, Actual = $364.0
# > Predicted = $1097.0, Actual = $1254.0
# > Predicted = $370.0, Actual = $335.0
# > Predicted = $486.0, Actual = $500.0
# > Predicted = $2062.0, Actual = $2108.0
# > Predicted = $1339.0, Actual = $1774.0
# > Predicted = $501.0, Actual = $541.0
# > Predicted = $1386.0, Actual = $1304.0
# > Predicted = $3075.0, Actual = $3230.0
# > Predicted = $1790.0, Actual = $1925.0
# > Predicted = $1416.0, Actual = $1462.0
# > Predicted = $2331.0, Actual = $3110.0
# > Predicted = $724.0, Actual = $637.0
# > Predicted = $1610.0, Actual = $1977.0
# > Predicted = $1283.0, Actual = $904.0
# > Predicted = $1415.0, Actual = $1065.0
# > Predicted = $279.0, Actual = $422.0
# > Predicted = $580.0, Actual = $933.0
# > Predicted = $2471.0, Actual = $1328.0
# > Predicted = $1278.0, Actual = $995.0
# > Predicted = $475.0, Actual = $458.0
# > Predicted = $1099.0, Actual = $855.0
# > Predicted = $520.0, Actual = $508.0
# > Predicted = $3471.0, Actual = $3017.0
# > Predicted = $706.0, Actual = $738.0
# > Predicted = $832.0, Actual = $648.0
# > Predicted = $323.0, Actual = $519.0
# > Predicted = $1967.0, Actual = $1794.0
# > Predicted = $1045.0, Actual = $1122.0
# > Predicted = $1183.0, Actual = $1136.0
# > Predicted = $1421.0, Actual = $1144.0
# > Predicted = $1358.0, Actual = $2396.0
# > Predicted = $1340.0, Actual = $1679.0
# > Predicted = $1073.0, Actual = $1589.0
# > Predicted = $803.0, Actual = $345.0
# > Predicted = $1718.0, Actual = $2453.0
# > Predicted = $1400.0, Actual = $1421.0
# > Predicted = $894.0, Actual = $783.0
# > Predicted = $646.0, Actual = $502.0
# > Predicted = $588.0, Actual = $724.0
# > Predicted = $2921.0, Actual = $3543.0
# > Predicted = $874.0, Actual = $876.0
# > Predicted = $1476.0, Actual = $2043.0
# > Predicted = $1701.0, Actual = $2133.0
# > Predicted = $229.0, Actual = $421.0
# > Predicted = $1237.0, Actual = $1340.0
# > Predicted = $1113.0, Actual = $506.0
# > Predicted = $2092.0, Actual = $2267.0
# > Predicted = $1424.0, Actual = $1737.0
# > Predicted = $1047.0, Actual = $1309.0
# > Predicted = $798.0, Actual = $904.0
# > Predicted = $590.0, Actual = $518.0
# > Predicted = $1368.0, Actual = $1388.0
# > Predicted = $1005.0, Actual = $875.0
# > Predicted = $1437.0, Actual = $1043.0
# > Predicted = $795.0, Actual = $1142.0
# > Predicted = $712.0, Actual = $635.0
# > Predicted = $214.0, Actual = $192.0
# > Predicted = $3167.0, Actual = $3056.0
# > Predicted = $980.0, Actual = $978.0
# > Predicted = $2218.0, Actual = $2042.0
# > Predicted = $1315.0, Actual = $1559.0
# > Predicted = $1913.0, Actual = $2009.0
# > Predicted = $881.0, Actual = $1381.0
# > Predicted = $990.0, Actual = $1299.0
# > Predicted = $271.0, Actual = $199.0
# > Predicted = $2483.0, Actual = $2323.0
# > Predicted = $2968.0, Actual = $1758.0
# > Predicted = $680.0, Actual = $193.0
# > Predicted = $890.0, Actual = $1073.0
# > Predicted = $1462.0, Actual = $2083.0
# > Predicted = $2544.0, Actual = $1967.0
# > Predicted = $2314.0, Actual = $1360.0
# > Predicted = $1454.0, Actual = $1551.0
# > Predicted = $2421.0, Actual = $1805.0
# > Predicted = $295.0, Actual = $266.0
# > Predicted = $1763.0, Actual = $1232.0
# > Predicted = $271.0, Actual = $270.0
# > Predicted = $1188.0, Actual = $1359.0
# > Predicted = $1024.0, Actual = $1284.0
# > Predicted = $1329.0, Actual = $1275.0
# > Predicted = $303.0, Actual = $190.0
# > Predicted = $780.0, Actual = $538.0
# > Predicted = $473.0, Actual = $534.0
# > Predicted = $765.0, Actual = $723.0
# > Predicted = $1082.0, Actual = $896.0
# > Predicted = $1006.0, Actual = $924.0
# > Predicted = $899.0, Actual = $809.0
# > Predicted = $712.0, Actual = $701.0
# > Predicted = $1717.0, Actual = $1007.0
# > Predicted = $809.0, Actual = $756.0
# > Predicted = $333.0, Actual = $581.0
# > Predicted = $650.0, Actual = $591.0
# > Predicted = $4189.0, Actual = $6777.0
# > Predicted = $1088.0, Actual = $1280.0
# > Predicted = $1392.0, Actual = $912.0
# > Predicted = $1780.0, Actual = $2146.0
# > Predicted = $1247.0, Actual = $1306.0
# > Predicted = $2535.0, Actual = $2701.0
# > Predicted = $1249.0, Actual = $907.0
# > Predicted = $1241.0, Actual = $1235.0
# > Predicted = $932.0, Actual = $1104.0
# > Predicted = $888.0, Actual = $702.0
# > Predicted = $643.0, Actual = $883.0
# > Predicted = $2108.0, Actual = $2209.0
# > Predicted = $1393.0, Actual = $1560.0
# > Predicted = $1675.0, Actual = $2045.0
# > Predicted = $1587.0, Actual = $1429.0
# > Predicted = $818.0, Actual = $556.0
# > Predicted = $890.0, Actual = $581.0
# > Predicted = $2054.0, Actual = $1628.0
# > Predicted = $761.0, Actual = $989.0
# > Predicted = $343.0, Actual = $319.0
# > Predicted = $934.0, Actual = $926.0
# > Predicted = $1095.0, Actual = $589.0
# > Predicted = $1617.0, Actual = $1533.0
# > Predicted = $858.0, Actual = $879.0
# > Predicted = $1180.0, Actual = $1930.0
# > Predicted = $1036.0, Actual = $931.0
# > Predicted = $2153.0, Actual = $1948.0
# > Predicted = $998.0, Actual = $1004.0
# > Predicted = $1545.0, Actual = $1125.0
# > Predicted = $2282.0, Actual = $2179.0
# > Predicted = $1607.0, Actual = $1973.0
# > Predicted = $1409.0, Actual = $1452.0
# > Predicted = $2222.0, Actual = $1985.0
# > Predicted = $769.0, Actual = $1187.0
# > Predicted = $1756.0, Actual = $1875.0
# > Predicted = $2061.0, Actual = $1643.0
# > Predicted = $383.0, Actual = $490.0
# > Predicted = $2473.0, Actual = $2340.0
# > Predicted = $704.0, Actual = $457.0
# > Predicted = $1544.0, Actual = $2344.0
# > Predicted = $1258.0, Actual = $1469.0
# > Predicted = $1331.0, Actual = $1018.0
# > Predicted = $558.0, Actual = $847.0
# > Predicted = $767.0, Actual = $1005.0
# > Predicted = $1372.0, Actual = $1483.0
# > Predicted = $988.0, Actual = $863.0
# > Predicted = $1615.0, Actual = $1062.0
# > Predicted = $1303.0, Actual = $1017.0
# > Predicted = $1908.0, Actual = $2568.0
# > Predicted = $921.0, Actual = $1286.0
# > Predicted = $462.0, Actual = $745.0
# > Predicted = $1765.0, Actual = $1730.0
# > Predicted = $369.0, Actual = $498.0
# > Predicted = $1854.0, Actual = $1513.0
# > Predicted = $3294.0, Actual = $3387.0
# > Predicted = $1347.0, Actual = $1401.0
# > Predicted = $764.0, Actual = $840.0
# > Predicted = $1511.0, Actual = $1273.0
# > Predicted = $1852.0, Actual = $1556.0
# > Predicted = $2800.0, Actual = $2717.0
# > Predicted = $2507.0, Actual = $2700.0
# > Predicted = $1798.0, Actual = $1669.0
# > Predicted = $1042.0, Actual = $1099.0
# > Predicted = $972.0, Actual = $769.0
# > Predicted = $838.0, Actual = $1462.0
# > Predicted = $1075.0, Actual = $1311.0
# > Predicted = $1408.0, Actual = $1357.0
# > Predicted = $1898.0, Actual = $2001.0
# > Predicted = $969.0, Actual = $1252.0
# > Predicted = $262.0, Actual = $231.0
# > Predicted = $261.0, Actual = $324.0
# > Predicted = $2781.0, Actual = $3027.0
# > Predicted = $408.0, Actual = $445.0
# > Predicted = $743.0, Actual = $1232.0
# > Predicted = $1288.0, Actual = $880.0
# > Predicted = $2354.0, Actual = $2210.0
# > Predicted = $2917.0, Actual = $2893.0
# > Predicted = $806.0, Actual = $1022.0
# > Predicted = $2313.0, Actual = $1933.0
# > Predicted = $917.0, Actual = $870.0
# > Predicted = $1235.0, Actual = $2640.0
# > Predicted = $865.0, Actual = $986.0
# > Predicted = $956.0, Actual = $981.0
# > Predicted = $873.0, Actual = $1005.0
# > Predicted = $1332.0, Actual = $2884.0
# > Predicted = $694.0, Actual = $499.0
# > Predicted = $2375.0, Actual = $2562.0
# > Predicted = $1532.0, Actual = $1453.0
# > Predicted = $1778.0, Actual = $1515.0
# > Predicted = $1329.0, Actual = $1206.0
# > Predicted = $429.0, Actual = $654.0
# > Predicted = $1163.0, Actual = $1042.0
# > Predicted = $425.0, Actual = $321.0
# > Predicted = $1176.0, Actual = $1273.0
# > Predicted = $823.0, Actual = $856.0
# > Predicted = $518.0, Actual = $535.0
# > Predicted = $1740.0, Actual = $1970.0
# > Predicted = $3077.0, Actual = $2213.0
# > Predicted = $1149.0, Actual = $1098.0
# > Predicted = $1725.0, Actual = $1534.0
# > Predicted = $581.0, Actual = $330.0
# > Predicted = $2157.0, Actual = $2216.0
# > Predicted = $3247.0, Actual = $2646.0
# > Predicted = $1847.0, Actual = $2416.0
# > Predicted = $5447.0, Actual = $5108.0
# > Predicted = $1184.0, Actual = $930.0
# > Predicted = $995.0, Actual = $860.0
# > Predicted = $593.0, Actual = $448.0
# > Predicted = $1201.0, Actual = $1188.0
# > Predicted = $952.0, Actual = $911.0
# > Predicted = $1151.0, Actual = $1096.0
# > Predicted = $1674.0, Actual = $1084.0
# > Predicted = $803.0, Actual = $795.0
# > Predicted = $188.0, Actual = $166.0
# > Predicted = $2656.0, Actual = $3634.0
# > Predicted = $722.0, Actual = $604.0
# > Predicted = $323.0, Actual = $351.0
# > Predicted = $1144.0, Actual = $1245.0
# > Predicted = $833.0, Actual = $750.0
# > Predicted = $909.0, Actual = $707.0
# > Predicted = $965.0, Actual = $864.0
# > Predicted = $726.0, Actual = $646.0
# > Predicted = $1012.0, Actual = $1208.0
# > Predicted = $1701.0, Actual = $1899.0
# > Predicted = $2906.0, Actual = $2222.0
# > Predicted = $1894.0, Actual = $1670.0
# > Predicted = $3833.0, Actual = $1663.0
# > Predicted = $664.0, Actual = $1178.0
# > Predicted = $985.0, Actual = $718.0
# > Predicted = $4410.0, Actual = $3638.0
# > Predicted = $1496.0, Actual = $2473.0
# > Predicted = $1513.0, Actual = $1445.0
# > Predicted = $1327.0, Actual = $1223.0
# > Predicted = $2503.0, Actual = $1324.0
# > Predicted = $2594.0, Actual = $2410.0
# > Predicted = $1496.0, Actual = $1283.0
# > Predicted = $2994.0, Actual = $3695.0
# > Predicted = $504.0, Actual = $638.0
# > Predicted = $678.0, Actual = $1002.0
# > Predicted = $793.0, Actual = $805.0
# > Predicted = $468.0, Actual = $400.0
# > Predicted = $397.0, Actual = $438.0
# > Predicted = $2013.0, Actual = $2030.0
# > Predicted = $1198.0, Actual = $1010.0
# > Predicted = $455.0, Actual = $533.0
# > Predicted = $1716.0, Actual = $1450.0
# > Predicted = $1092.0, Actual = $1181.0
# > Predicted = $1271.0, Actual = $1424.0
# > Predicted = $1119.0, Actual = $1035.0
# > Predicted = $1119.0, Actual = $1395.0
# > Predicted = $1019.0, Actual = $1126.0
# > Predicted = $549.0, Actual = $415.0
# > Predicted = $758.0, Actual = $752.0
# > Predicted = $4698.0, Actual = $4519.0
# > Predicted = $883.0, Actual = $823.0
# > Predicted = $2201.0, Actual = $2003.0
# > Predicted = $2001.0, Actual = $2162.0
# > Predicted = $2741.0, Actual = $2656.0
# > Predicted = $1750.0, Actual = $988.0
# > Predicted = $2154.0, Actual = $770.0
# > Predicted = $1247.0, Actual = $1731.0
# > Predicted = $1124.0, Actual = $866.0
# > Predicted = $915.0, Actual = $1189.0
# > Predicted = $697.0, Actual = $720.0
# > Predicted = $731.0, Actual = $708.0
# > Predicted = $1092.0, Actual = $1351.0
# > Predicted = $647.0, Actual = $676.0
# > Predicted = $2330.0, Actual = $1706.0
# > Predicted = $978.0, Actual = $1000.0
# > Predicted = $2932.0, Actual = $2696.0
# > Predicted = $1613.0, Actual = $1386.0
# > Predicted = $1104.0, Actual = $1172.0
# > Predicted = $2211.0, Actual = $1937.0
# > Predicted = $2509.0, Actual = $2431.0
# > Predicted = $3245.0, Actual = $4095.0
# > Predicted = $711.0, Actual = $901.0
# > Predicted = $1586.0, Actual = $1211.0
# > Predicted = $1659.0, Actual = $1984.0
# > Predicted = $887.0, Actual = $1163.0
# > Predicted = $1325.0, Actual = $1228.0
# > Predicted = $2416.0, Actual = $2342.0
# > Predicted = $1103.0, Actual = $1285.0
# > Predicted = $998.0, Actual = $1300.0
# > Predicted = $649.0, Actual = $589.0
# > Predicted = $962.0, Actual = $929.0
# > Predicted = $591.0, Actual = $602.0
# > Predicted = $772.0, Actual = $574.0
# > Predicted = $2093.0, Actual = $2064.0
# > Predicted = $412.0, Actual = $440.0
# > Predicted = $1092.0, Actual = $1023.0
# > Predicted = $1568.0, Actual = $1395.0
# > Predicted = $298.0, Actual = $340.0
# > Predicted = $1016.0, Actual = $1056.0
# > Predicted = $1997.0, Actual = $2135.0
# > Predicted = $925.0, Actual = $1105.0
# > Predicted = $1033.0, Actual = $1054.0
# > Predicted = $1998.0, Actual = $2141.0
# > Predicted = $867.0, Actual = $1294.0
# > Predicted = $1033.0, Actual = $966.0
# > Predicted = $824.0, Actual = $600.0
# > Predicted = $2390.0, Actual = $3904.0
# > Predicted = $1317.0, Actual = $780.0
# > Predicted = $1097.0, Actual = $1717.0
# > Predicted = $1549.0, Actual = $1691.0
# > Predicted = $1493.0, Actual = $1621.0
# > Predicted = $811.0, Actual = $784.0
# > Predicted = $2048.0, Actual = $1496.0
# > Predicted = $574.0, Actual = $499.0
# > Predicted = $681.0, Actual = $531.0
# > Predicted = $867.0, Actual = $782.0
# > Predicted = $617.0, Actual = $1159.0
# > Predicted = $1325.0, Actual = $1619.0
# > Predicted = $745.0, Actual = $855.0
# > Predicted = $1827.0, Actual = $1625.0
# > Predicted = $1667.0, Actual = $1613.0
# > Predicted = $1866.0, Actual = $1898.0
# > Predicted = $2768.0, Actual = $2783.0
# > Predicted = $1042.0, Actual = $865.0
# > Predicted = $537.0, Actual = $259.0
# > Predicted = $1019.0, Actual = $844.0
# > Predicted = $408.0, Actual = $257.0
# > Predicted = $942.0, Actual = $1162.0
# > Predicted = $2445.0, Actual = $1153.0
# > Predicted = $617.0, Actual = $644.0
# > Predicted = $1588.0, Actual = $2283.0
# > Predicted = $895.0, Actual = $805.0
# > Predicted = $2565.0, Actual = $2442.0
# > Predicted = $1886.0, Actual = $1874.0
# > Predicted = $1435.0, Actual = $1372.0
# > Predicted = $768.0, Actual = $759.0
# > Predicted = $2982.0, Actual = $3511.0
# > Predicted = $695.0, Actual = $612.0
# > Predicted = $520.0, Actual = $1022.0
# > Predicted = $1535.0, Actual = $1685.0
# > Predicted = $721.0, Actual = $668.0
# > Predicted = $2533.0, Actual = $3422.0
# > Predicted = $2765.0, Actual = $3018.0
# > Predicted = $404.0, Actual = $410.0
# > Predicted = $2470.0, Actual = $1570.0
# > Predicted = $2203.0, Actual = $1778.0
# > Predicted = $896.0, Actual = $1235.0
# > Predicted = $3108.0, Actual = $2894.0
# > Predicted = $442.0, Actual = $699.0
# > Predicted = $278.0, Actual = $601.0
# > Predicted = $3098.0, Actual = $2559.0
# > Predicted = $254.0, Actual = $330.0
# > Predicted = $3365.0, Actual = $3063.0
# > Predicted = $394.0, Actual = $370.0
# > Predicted = $1832.0, Actual = $1828.0
# > Predicted = $1688.0, Actual = $1815.0
# > Predicted = $410.0, Actual = $785.0
# > Predicted = $884.0, Actual = $901.0
# > Predicted = $846.0, Actual = $874.0
# > Predicted = $908.0, Actual = $1092.0
# > Predicted = $1685.0, Actual = $1835.0
# > Predicted = $1196.0, Actual = $855.0
# > Predicted = $441.0, Actual = $500.0
# > Predicted = $1209.0, Actual = $1186.0
# > Predicted = $1858.0, Actual = $1307.0
# > Predicted = $733.0, Actual = $526.0
# > Predicted = $973.0, Actual = $1254.0
# > Predicted = $2627.0, Actual = $1785.0
# > Predicted = $984.0, Actual = $1403.0
# > Predicted = $1480.0, Actual = $1362.0
# > Predicted = $974.0, Actual = $1375.0
# > Predicted = $1200.0, Actual = $1058.0
# > Predicted = $827.0, Actual = $542.0
# > Predicted = $2415.0, Actual = $2308.0
# > Predicted = $1004.0, Actual = $1202.0
# > Predicted = $2053.0, Actual = $2332.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-64da31264f99> in <module>
#      78     accuracy = get_Accuracy(testSet, predictions)
#      79     print('Accuracy: ' + repr(accuracy))
# ---> 80 main()
#
# <ipython-input-24-64da31264f99> in main()
#      76         print('> Predicted = $' + repr(result) + ', Actual = $' + repr(testSet[x][-1]))
#      77         #print('> Actual = ' + repr(testSet[x][-1]) + ', Predicted = ' + repr(result))
# ---> 78     accuracy = get_Accuracy(testSet, predictions)
#      79     print('Accuracy: ' + repr(accuracy))
#      80 main()
#
# <ipython-input-24-64da31264f99> in get_Accuracy(testSet, predictions)
#      57
#      58 def get_Accuracy(testSet, predictions):
# ---> 59     return mean_squared_error(testSet, predictions)
#      60
#      61 def main():
#
# ~/opt/anaconda3/envs/python-r/lib/python3.7/site-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     250     """
#     251     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 252         y_true, y_pred, multioutput)
#     253     check_consistent_length(y_true, y_pred, sample_weight)
#     254     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# ~/opt/anaconda3/envs/python-r/lib/python3.7/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      94     if y_true.shape[1] != y_pred.shape[1]:
#      95         raise ValueError("y_true and y_pred have different number of output "
# ---> 96                          "({0}!={1})".format(y_true.shape[1], y_pred.shape[1]))
#      97
#      98     n_outputs = y_true.shape[1]
#
# ValueError: y_true and y_pred have different number of output (24!=1)
