# %%
import csv
import random
import math
import operator
from sklearn.metrics import mean_squared_error

# Loading Data Set
def load_Dataset(filename, split, trainingSet=[] , testSet=[]):
    with open(filename, 'r') as csvfile:
        lines = csv.reader(csvfile)
        dataset = list(lines)
        for x in range(len(dataset)-1):
            for y in range(24):
                dataset[x][y] = float(dataset[x][y])
            if random.random() < split:
                trainingSet.append(dataset[x])
            else:
                testSet.append(dataset[x])

# Euclidean distance algorithm for training set + test instance
# length controls the which fields to include in distance calculation

def euclidean_Distance(instance1, instance2, length):
    distance = 0
    for x in range(length):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)

# Finding the neighbors of the test instance in the training set

def get_Neighbors(trainingSet, testInstance, k):
    distances = []
    length = len(testInstance)-1
    for x in range(len(trainingSet)):
        dist = euclidean_Distance(testInstance, trainingSet[x], length)
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors
 
# Voting on all the neighbors to classify the test instance 

def get_Response(neighbors):
    Votes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][-1]
        if response in Votes:
            Votes[response] += 1
        else:
            Votes[response] = 1
    sortedVotes = sorted(Votes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]
 
# Accuracy test

def get_Accuracy(testSet, predictions):
    correct = 0
    for x in range(len(testSet)):
        if (testSet[x][-1] <predictions[x]*1.25 and testSet[x][-1] >predictions[x]*0.75) :
            correct += 1
    return (correct/float(len(testSet))) * 100.0

def main():
    # Format Date
    trainingSet=[]
    testSet=[]
    split = 0.95
    load_Dataset('finalinputs.csv', split, trainingSet, testSet)
    print ('Train set: ' + repr(len(trainingSet)))
    print ('Test set: ' + repr(len(testSet)) + '\n') 
    # generate predictions
    predictions=[]
    k = 9
    for x in range(len(testSet)):
        neighbors = get_Neighbors(trainingSet, testSet[x], k)
        result = get_Response(neighbors)
        predictions.append(result)
        print('> Predicted = $' + repr(result) + ', Actual = $' + repr(testSet[x][-1]))
        #print('> Actual = ' + repr(testSet[x][-1]) + ', Predicted = ' + repr(result))
    accuracy = get_Accuracy(testSet, predictions)
    print('Accuracy: ' + repr(accuracy))
main()
# Out:
# Train set: 11438
# Test set: 644
#
# > Predicted = $1455.0, Actual = $1327.0
# > Predicted = $1430.0, Actual = $1435.0
# > Predicted = $1459.0, Actual = $1196.0
# > Predicted = $1351.0, Actual = $995.0
# > Predicted = $492.0, Actual = $654.0
# > Predicted = $1048.0, Actual = $940.0
# > Predicted = $701.0, Actual = $712.0
# > Predicted = $2153.0, Actual = $2259.0
# > Predicted = $749.0, Actual = $524.0
# > Predicted = $1147.0, Actual = $934.0
# > Predicted = $578.0, Actual = $590.0
# > Predicted = $293.0, Actual = $535.0
# > Predicted = $1270.0, Actual = $1228.0
# > Predicted = $500.0, Actual = $564.0
# > Predicted = $2431.0, Actual = $2092.0
# > Predicted = $967.0, Actual = $1042.0
# > Predicted = $3059.0, Actual = $4276.0
# > Predicted = $952.0, Actual = $978.0
# > Predicted = $1008.0, Actual = $1036.0
# > Predicted = $722.0, Actual = $764.0
# > Predicted = $2710.0, Actual = $2820.0
# > Predicted = $674.0, Actual = $766.0
# > Predicted = $957.0, Actual = $1258.0
# > Predicted = $668.0, Actual = $768.0
# > Predicted = $1328.0, Actual = $1115.0
# > Predicted = $711.0, Actual = $751.0
# > Predicted = $1985.0, Actual = $1977.0
# > Predicted = $909.0, Actual = $685.0
# > Predicted = $588.0, Actual = $555.0
# > Predicted = $3355.0, Actual = $3831.0
# > Predicted = $538.0, Actual = $539.0
# > Predicted = $2629.0, Actual = $2057.0
# > Predicted = $268.0, Actual = $422.0
# > Predicted = $877.0, Actual = $1159.0
# > Predicted = $1129.0, Actual = $1575.0
# > Predicted = $1548.0, Actual = $1298.0
# > Predicted = $669.0, Actual = $413.0
# > Predicted = $1382.0, Actual = $1039.0
# > Predicted = $943.0, Actual = $1116.0
# > Predicted = $806.0, Actual = $943.0
# > Predicted = $1533.0, Actual = $2160.0
# > Predicted = $2042.0, Actual = $2054.0
# > Predicted = $1184.0, Actual = $1195.0
# > Predicted = $621.0, Actual = $679.0
# > Predicted = $1331.0, Actual = $1174.0
# > Predicted = $773.0, Actual = $721.0
# > Predicted = $445.0, Actual = $380.0
# > Predicted = $2811.0, Actual = $2690.0
# > Predicted = $1374.0, Actual = $1196.0
# > Predicted = $855.0, Actual = $852.0
# > Predicted = $533.0, Actual = $450.0
# > Predicted = $2054.0, Actual = $1574.0
# > Predicted = $697.0, Actual = $862.0
# > Predicted = $1285.0, Actual = $1248.0
# > Predicted = $2613.0, Actual = $2974.0
# > Predicted = $987.0, Actual = $781.0
# > Predicted = $1039.0, Actual = $876.0
# > Predicted = $632.0, Actual = $1013.0
# > Predicted = $3498.0, Actual = $2803.0
# > Predicted = $448.0, Actual = $241.0
# > Predicted = $591.0, Actual = $773.0
# > Predicted = $1648.0, Actual = $1717.0
# > Predicted = $903.0, Actual = $917.0
# > Predicted = $2100.0, Actual = $2425.0
# > Predicted = $584.0, Actual = $435.0
# > Predicted = $1517.0, Actual = $1062.0
# > Predicted = $962.0, Actual = $923.0
# > Predicted = $1722.0, Actual = $2939.0
# > Predicted = $823.0, Actual = $1034.0
# > Predicted = $1716.0, Actual = $1804.0
# > Predicted = $2176.0, Actual = $1745.0
# > Predicted = $2232.0, Actual = $2040.0
# > Predicted = $1592.0, Actual = $1087.0
# > Predicted = $651.0, Actual = $738.0
# > Predicted = $397.0, Actual = $396.0
# > Predicted = $1162.0, Actual = $942.0
# > Predicted = $1803.0, Actual = $1428.0
# > Predicted = $2630.0, Actual = $2789.0
# > Predicted = $299.0, Actual = $350.0
# > Predicted = $1338.0, Actual = $1031.0
# > Predicted = $643.0, Actual = $816.0
# > Predicted = $2991.0, Actual = $2514.0
# > Predicted = $2445.0, Actual = $2459.0
# > Predicted = $848.0, Actual = $581.0
# > Predicted = $413.0, Actual = $506.0
# > Predicted = $1364.0, Actual = $1380.0
# > Predicted = $2536.0, Actual = $2828.0
# > Predicted = $2178.0, Actual = $2246.0
# > Predicted = $1833.0, Actual = $1674.0
# > Predicted = $1245.0, Actual = $1204.0
# > Predicted = $1208.0, Actual = $1425.0
# > Predicted = $648.0, Actual = $615.0
# > Predicted = $1033.0, Actual = $1226.0
# > Predicted = $2330.0, Actual = $2114.0
# > Predicted = $1032.0, Actual = $1077.0
# > Predicted = $743.0, Actual = $522.0
# > Predicted = $1024.0, Actual = $849.0
# > Predicted = $373.0, Actual = $418.0
# > Predicted = $1372.0, Actual = $1274.0
# > Predicted = $2134.0, Actual = $1796.0
# > Predicted = $1898.0, Actual = $1955.0
# > Predicted = $1590.0, Actual = $1091.0
# > Predicted = $1163.0, Actual = $852.0
# > Predicted = $1035.0, Actual = $638.0
# > Predicted = $936.0, Actual = $1379.0
# > Predicted = $1893.0, Actual = $1803.0
# > Predicted = $1055.0, Actual = $1391.0
# > Predicted = $1779.0, Actual = $2587.0
# > Predicted = $1842.0, Actual = $1227.0
# > Predicted = $1995.0, Actual = $1860.0
# > Predicted = $1245.0, Actual = $1161.0
# > Predicted = $1629.0, Actual = $1805.0
# > Predicted = $984.0, Actual = $941.0
# > Predicted = $1241.0, Actual = $1551.0
# > Predicted = $1525.0, Actual = $1830.0
# > Predicted = $2869.0, Actual = $1663.0
# > Predicted = $406.0, Actual = $511.0
# > Predicted = $832.0, Actual = $773.0
# > Predicted = $470.0, Actual = $526.0
# > Predicted = $1113.0, Actual = $1166.0
# > Predicted = $3245.0, Actual = $2460.0
# > Predicted = $812.0, Actual = $851.0
# > Predicted = $1712.0, Actual = $1265.0
# > Predicted = $629.0, Actual = $460.0
# > Predicted = $3157.0, Actual = $2408.0
# > Predicted = $1581.0, Actual = $1975.0
# > Predicted = $846.0, Actual = $653.0
# > Predicted = $1913.0, Actual = $2079.0
# > Predicted = $1298.0, Actual = $1229.0
# > Predicted = $2508.0, Actual = $2502.0
# > Predicted = $1176.0, Actual = $1282.0
# > Predicted = $507.0, Actual = $555.0
# > Predicted = $860.0, Actual = $712.0
# > Predicted = $1327.0, Actual = $1151.0
# > Predicted = $1048.0, Actual = $1130.0
# > Predicted = $843.0, Actual = $860.0
# > Predicted = $1661.0, Actual = $1418.0
# > Predicted = $1012.0, Actual = $869.0
# > Predicted = $1232.0, Actual = $1194.0
# > Predicted = $1016.0, Actual = $886.0
# > Predicted = $2132.0, Actual = $1443.0
# > Predicted = $1005.0, Actual = $870.0
# > Predicted = $1354.0, Actual = $1230.0
# > Predicted = $1447.0, Actual = $2485.0
# > Predicted = $648.0, Actual = $716.0
# > Predicted = $470.0, Actual = $677.0
# > Predicted = $2496.0, Actual = $1859.0
# > Predicted = $519.0, Actual = $502.0
# > Predicted = $1643.0, Actual = $2260.0
# > Predicted = $799.0, Actual = $1385.0
# > Predicted = $2331.0, Actual = $2543.0
# > Predicted = $423.0, Actual = $646.0
# > Predicted = $763.0, Actual = $788.0
# > Predicted = $1861.0, Actual = $2604.0
# > Predicted = $649.0, Actual = $1306.0
# > Predicted = $2163.0, Actual = $2494.0
# > Predicted = $2642.0, Actual = $1832.0
# > Predicted = $3246.0, Actual = $2744.0
# > Predicted = $3061.0, Actual = $4227.0
# > Predicted = $2069.0, Actual = $2001.0
# > Predicted = $855.0, Actual = $847.0
# > Predicted = $320.0, Actual = $350.0
# > Predicted = $1264.0, Actual = $958.0
# > Predicted = $503.0, Actual = $665.0
# > Predicted = $500.0, Actual = $477.0
# > Predicted = $1246.0, Actual = $1292.0
# > Predicted = $1862.0, Actual = $1307.0
# > Predicted = $658.0, Actual = $912.0
# > Predicted = $820.0, Actual = $353.0
# > Predicted = $1311.0, Actual = $1240.0
# > Predicted = $5263.0, Actual = $5364.0
# > Predicted = $1064.0, Actual = $1198.0
# > Predicted = $1008.0, Actual = $726.0
# > Predicted = $3637.0, Actual = $6069.0
# > Predicted = $633.0, Actual = $900.0
# > Predicted = $1297.0, Actual = $1106.0
# > Predicted = $747.0, Actual = $629.0
# > Predicted = $1104.0, Actual = $1248.0
# > Predicted = $1130.0, Actual = $1026.0
# > Predicted = $406.0, Actual = $593.0
# > Predicted = $848.0, Actual = $550.0
# > Predicted = $2660.0, Actual = $4136.0
# > Predicted = $668.0, Actual = $434.0
# > Predicted = $3082.0, Actual = $1915.0
# > Predicted = $2414.0, Actual = $2624.0
# > Predicted = $1232.0, Actual = $1648.0
# > Predicted = $425.0, Actual = $678.0
# > Predicted = $706.0, Actual = $700.0
# > Predicted = $588.0, Actual = $1075.0
# > Predicted = $567.0, Actual = $1363.0
# > Predicted = $451.0, Actual = $411.0
# > Predicted = $793.0, Actual = $666.0
# > Predicted = $1496.0, Actual = $2402.0
# > Predicted = $1040.0, Actual = $548.0
# > Predicted = $3887.0, Actual = $3710.0
# > Predicted = $1211.0, Actual = $779.0
# > Predicted = $131.0, Actual = $178.0
# > Predicted = $411.0, Actual = $525.0
# > Predicted = $760.0, Actual = $809.0
# > Predicted = $737.0, Actual = $1138.0
# > Predicted = $1097.0, Actual = $1520.0
# > Predicted = $795.0, Actual = $678.0
# > Predicted = $464.0, Actual = $502.0
# > Predicted = $392.0, Actual = $454.0
# > Predicted = $1643.0, Actual = $2539.0
# > Predicted = $941.0, Actual = $1309.0
# > Predicted = $1323.0, Actual = $3370.0
# > Predicted = $1049.0, Actual = $1113.0
# > Predicted = $1227.0, Actual = $1601.0
# > Predicted = $945.0, Actual = $1022.0
# > Predicted = $1319.0, Actual = $2086.0
# > Predicted = $1008.0, Actual = $1873.0
# > Predicted = $1596.0, Actual = $2003.0
# > Predicted = $2428.0, Actual = $2153.0
# > Predicted = $1908.0, Actual = $2616.0
# > Predicted = $931.0, Actual = $580.0
# > Predicted = $643.0, Actual = $1361.0
# > Predicted = $2216.0, Actual = $2253.0
# > Predicted = $594.0, Actual = $425.0
# > Predicted = $1264.0, Actual = $2009.0
# > Predicted = $1536.0, Actual = $1353.0
# > Predicted = $867.0, Actual = $973.0
# > Predicted = $2539.0, Actual = $1743.0
# > Predicted = $2402.0, Actual = $2963.0
# > Predicted = $271.0, Actual = $470.0
# > Predicted = $862.0, Actual = $1073.0
# > Predicted = $790.0, Actual = $729.0
# > Predicted = $1198.0, Actual = $1674.0
# > Predicted = $740.0, Actual = $664.0
# > Predicted = $2324.0, Actual = $2155.0
# > Predicted = $1112.0, Actual = $2007.0
# > Predicted = $833.0, Actual = $860.0
# > Predicted = $1355.0, Actual = $1323.0
# > Predicted = $2667.0, Actual = $2567.0
# > Predicted = $984.0, Actual = $769.0
# > Predicted = $1583.0, Actual = $1542.0
# > Predicted = $600.0, Actual = $610.0
# > Predicted = $994.0, Actual = $886.0
# > Predicted = $763.0, Actual = $557.0
# > Predicted = $581.0, Actual = $656.0
# > Predicted = $1192.0, Actual = $1055.0
# > Predicted = $7701.0, Actual = $10740.0
# > Predicted = $1636.0, Actual = $1233.0
# > Predicted = $580.0, Actual = $772.0
# > Predicted = $2400.0, Actual = $3388.0
# > Predicted = $1820.0, Actual = $2006.0
# > Predicted = $1468.0, Actual = $1198.0
# > Predicted = $578.0, Actual = $580.0
# > Predicted = $4432.0, Actual = $4805.0
# > Predicted = $2780.0, Actual = $2394.0
# > Predicted = $2422.0, Actual = $2147.0
# > Predicted = $580.0, Actual = $684.0
# > Predicted = $1176.0, Actual = $884.0
# > Predicted = $756.0, Actual = $809.0
# > Predicted = $459.0, Actual = $430.0
# > Predicted = $876.0, Actual = $872.0
# > Predicted = $1416.0, Actual = $1462.0
# > Predicted = $2900.0, Actual = $1943.0
# > Predicted = $2997.0, Actual = $1781.0
# > Predicted = $3889.0, Actual = $3160.0
# > Predicted = $1283.0, Actual = $904.0
# > Predicted = $674.0, Actual = $896.0
# > Predicted = $1598.0, Actual = $1410.0
# > Predicted = $1677.0, Actual = $1759.0
# > Predicted = $651.0, Actual = $1151.0
# > Predicted = $1287.0, Actual = $1089.0
# > Predicted = $1240.0, Actual = $1787.0
# > Predicted = $514.0, Actual = $641.0
# > Predicted = $2792.0, Actual = $2520.0
# > Predicted = $865.0, Actual = $1042.0
# > Predicted = $373.0, Actual = $365.0
# > Predicted = $652.0, Actual = $653.0
# > Predicted = $3127.0, Actual = $4361.0
# > Predicted = $1354.0, Actual = $1443.0
# > Predicted = $1347.0, Actual = $1613.0
# > Predicted = $1177.0, Actual = $1626.0
# > Predicted = $4530.0, Actual = $4491.0
# > Predicted = $923.0, Actual = $1335.0
# > Predicted = $1165.0, Actual = $1859.0
# > Predicted = $693.0, Actual = $477.0
# > Predicted = $1020.0, Actual = $985.0
# > Predicted = $367.0, Actual = $824.0
# > Predicted = $859.0, Actual = $690.0
# > Predicted = $323.0, Actual = $519.0
# > Predicted = $2681.0, Actual = $2582.0
# > Predicted = $1761.0, Actual = $1860.0
# > Predicted = $815.0, Actual = $835.0
# > Predicted = $4295.0, Actual = $3427.0
# > Predicted = $987.0, Actual = $983.0
# > Predicted = $801.0, Actual = $928.0
# > Predicted = $1385.0, Actual = $1665.0
# > Predicted = $2266.0, Actual = $2033.0
# > Predicted = $1456.0, Actual = $1246.0
# > Predicted = $867.0, Actual = $1022.0
# > Predicted = $792.0, Actual = $773.0
# > Predicted = $397.0, Actual = $445.0
# > Predicted = $2335.0, Actual = $1727.0
# > Predicted = $829.0, Actual = $777.0
# > Predicted = $1746.0, Actual = $1726.0
# > Predicted = $826.0, Actual = $768.0
# > Predicted = $664.0, Actual = $1068.0
# > Predicted = $1590.0, Actual = $1485.0
# > Predicted = $1424.0, Actual = $1737.0
# > Predicted = $606.0, Actual = $486.0
# > Predicted = $1368.0, Actual = $1388.0
# > Predicted = $1668.0, Actual = $3790.0
# > Predicted = $848.0, Actual = $962.0
# > Predicted = $1160.0, Actual = $853.0
# > Predicted = $500.0, Actual = $493.0
# > Predicted = $1415.0, Actual = $1521.0
# > Predicted = $984.0, Actual = $1039.0
# > Predicted = $938.0, Actual = $584.0
# > Predicted = $633.0, Actual = $735.0
# > Predicted = $619.0, Actual = $1080.0
# > Predicted = $969.0, Actual = $793.0
# > Predicted = $374.0, Actual = $285.0
# > Predicted = $2459.0, Actual = $2860.0
# > Predicted = $2562.0, Actual = $2765.0
# > Predicted = $2942.0, Actual = $3408.0
# > Predicted = $228.0, Actual = $339.0
# > Predicted = $745.0, Actual = $764.0
# > Predicted = $1793.0, Actual = $1843.0
# > Predicted = $685.0, Actual = $482.0
# > Predicted = $2765.0, Actual = $2775.0
# > Predicted = $886.0, Actual = $849.0
# > Predicted = $1200.0, Actual = $2117.0
# > Predicted = $1615.0, Actual = $1700.0
# > Predicted = $619.0, Actual = $514.0
# > Predicted = $1746.0, Actual = $1217.0
# > Predicted = $1476.0, Actual = $1781.0
# > Predicted = $753.0, Actual = $799.0
# > Predicted = $1518.0, Actual = $1561.0
# > Predicted = $609.0, Actual = $579.0
# > Predicted = $755.0, Actual = $662.0
# > Predicted = $1024.0, Actual = $1284.0
# > Predicted = $1842.0, Actual = $1319.0
# > Predicted = $1110.0, Actual = $595.0
# > Predicted = $922.0, Actual = $1467.0
# > Predicted = $1790.0, Actual = $1967.0
# > Predicted = $970.0, Actual = $1512.0
# > Predicted = $395.0, Actual = $514.0
# > Predicted = $1006.0, Actual = $924.0
# > Predicted = $966.0, Actual = $670.0
# > Predicted = $2465.0, Actual = $1876.0
# > Predicted = $1970.0, Actual = $2286.0
# > Predicted = $761.0, Actual = $435.0
# > Predicted = $773.0, Actual = $585.0
# > Predicted = $1129.0, Actual = $965.0
# > Predicted = $1103.0, Actual = $695.0
# > Predicted = $1127.0, Actual = $1264.0
# > Predicted = $1131.0, Actual = $505.0
# > Predicted = $877.0, Actual = $825.0
# > Predicted = $1249.0, Actual = $907.0
# > Predicted = $643.0, Actual = $883.0
# > Predicted = $1964.0, Actual = $1760.0
# > Predicted = $1598.0, Actual = $1685.0
# > Predicted = $2117.0, Actual = $1395.0
# > Predicted = $1144.0, Actual = $1178.0
# > Predicted = $1862.0, Actual = $1662.0
# > Predicted = $752.0, Actual = $674.0
# > Predicted = $1532.0, Actual = $1221.0
# > Predicted = $1687.0, Actual = $1339.0
# > Predicted = $263.0, Actual = $330.0
# > Predicted = $417.0, Actual = $410.0
# > Predicted = $1223.0, Actual = $1173.0
# > Predicted = $982.0, Actual = $654.0
# > Predicted = $565.0, Actual = $662.0
# > Predicted = $7516.0, Actual = $6804.0
# > Predicted = $893.0, Actual = $775.0
# > Predicted = $837.0, Actual = $899.0
# > Predicted = $1392.0, Actual = $1271.0
# > Predicted = $1465.0, Actual = $1149.0
# > Predicted = $1147.0, Actual = $1084.0
# > Predicted = $1361.0, Actual = $1150.0
# > Predicted = $634.0, Actual = $464.0
# > Predicted = $855.0, Actual = $788.0
# > Predicted = $726.0, Actual = $773.0
# > Predicted = $1504.0, Actual = $1309.0
# > Predicted = $473.0, Actual = $423.0
# > Predicted = $1503.0, Actual = $879.0
# > Predicted = $1097.0, Actual = $1207.0
# > Predicted = $789.0, Actual = $1681.0
# > Predicted = $1006.0, Actual = $643.0
# > Predicted = $997.0, Actual = $868.0
# > Predicted = $918.0, Actual = $506.0
# > Predicted = $1126.0, Actual = $1217.0
# > Predicted = $1042.0, Actual = $964.0
# > Predicted = $1416.0, Actual = $1399.0
# > Predicted = $1038.0, Actual = $1694.0
# > Predicted = $1230.0, Actual = $1542.0
# > Predicted = $1416.0, Actual = $1207.0
# > Predicted = $383.0, Actual = $490.0
# > Predicted = $1462.0, Actual = $1355.0
# > Predicted = $533.0, Actual = $370.0
# > Predicted = $704.0, Actual = $457.0
# > Predicted = $130.0, Actual = $114.0
# > Predicted = $1698.0, Actual = $1508.0
# > Predicted = $812.0, Actual = $1302.0
# > Predicted = $479.0, Actual = $408.0
# > Predicted = $1002.0, Actual = $805.0
# > Predicted = $1759.0, Actual = $1388.0
# > Predicted = $1615.0, Actual = $1062.0
# > Predicted = $1026.0, Actual = $1310.0
# > Predicted = $2030.0, Actual = $2013.0
# > Predicted = $1483.0, Actual = $1433.0
# > Predicted = $1073.0, Actual = $846.0
# > Predicted = $373.0, Actual = $408.0
# > Predicted = $1658.0, Actual = $2649.0
# > Predicted = $1702.0, Actual = $1255.0
# > Predicted = $1784.0, Actual = $2064.0
# > Predicted = $1278.0, Actual = $1547.0
# > Predicted = $654.0, Actual = $969.0
# > Predicted = $3294.0, Actual = $3387.0
# > Predicted = $1487.0, Actual = $1856.0
# > Predicted = $761.0, Actual = $699.0
# > Predicted = $679.0, Actual = $893.0
# > Predicted = $689.0, Actual = $868.0
# > Predicted = $2105.0, Actual = $1916.0
# > Predicted = $1170.0, Actual = $1107.0
# > Predicted = $1968.0, Actual = $2002.0
# > Predicted = $8055.0, Actual = $7041.0
# > Predicted = $2391.0, Actual = $1707.0
# > Predicted = $1488.0, Actual = $1354.0
# > Predicted = $298.0, Actual = $236.0
# > Predicted = $1042.0, Actual = $1099.0
# > Predicted = $472.0, Actual = $417.0
# > Predicted = $838.0, Actual = $1462.0
# > Predicted = $437.0, Actual = $729.0
# > Predicted = $1468.0, Actual = $784.0
# > Predicted = $1087.0, Actual = $862.0
# > Predicted = $1250.0, Actual = $1201.0
# > Predicted = $1104.0, Actual = $1229.0
# > Predicted = $3651.0, Actual = $3791.0
# > Predicted = $2503.0, Actual = $1816.0
# > Predicted = $1847.0, Actual = $1306.0
# > Predicted = $1252.0, Actual = $1190.0
# > Predicted = $1797.0, Actual = $1395.0
# > Predicted = $1842.0, Actual = $1689.0
# > Predicted = $1692.0, Actual = $1374.0
# > Predicted = $460.0, Actual = $411.0
# > Predicted = $260.0, Actual = $259.0
# > Predicted = $2130.0, Actual = $2225.0
# > Predicted = $2181.0, Actual = $2233.0
# > Predicted = $1975.0, Actual = $1826.0
# > Predicted = $1358.0, Actual = $1253.0
# > Predicted = $1760.0, Actual = $1917.0
# > Predicted = $1782.0, Actual = $1586.0
# > Predicted = $1847.0, Actual = $2225.0
# > Predicted = $516.0, Actual = $691.0
# > Predicted = $748.0, Actual = $790.0
# > Predicted = $2646.0, Actual = $3247.0
# > Predicted = $404.0, Actual = $722.0
# > Predicted = $414.0, Actual = $362.0
# > Predicted = $968.0, Actual = $1095.0
# > Predicted = $519.0, Actual = $1027.0
# > Predicted = $496.0, Actual = $363.0
# > Predicted = $1517.0, Actual = $1405.0
# > Predicted = $899.0, Actual = $661.0
# > Predicted = $1329.0, Actual = $1206.0
# > Predicted = $699.0, Actual = $654.0
# > Predicted = $1235.0, Actual = $1367.0
# > Predicted = $838.0, Actual = $688.0
# > Predicted = $969.0, Actual = $958.0
# > Predicted = $2988.0, Actual = $2629.0
# > Predicted = $1664.0, Actual = $1673.0
# > Predicted = $999.0, Actual = $1011.0
# > Predicted = $1593.0, Actual = $2475.0
# > Predicted = $590.0, Actual = $543.0
# > Predicted = $1847.0, Actual = $2416.0
# > Predicted = $719.0, Actual = $892.0
# > Predicted = $897.0, Actual = $945.0
# > Predicted = $2373.0, Actual = $2496.0
# > Predicted = $1444.0, Actual = $1685.0
# > Predicted = $730.0, Actual = $740.0
# > Predicted = $839.0, Actual = $778.0
# > Predicted = $2060.0, Actual = $2393.0
# > Predicted = $1053.0, Actual = $833.0
# > Predicted = $446.0, Actual = $484.0
# > Predicted = $2179.0, Actual = $1541.0
# > Predicted = $1151.0, Actual = $1096.0
# > Predicted = $815.0, Actual = $828.0
# > Predicted = $241.0, Actual = $320.0
# > Predicted = $2276.0, Actual = $1537.0
# > Predicted = $864.0, Actual = $1664.0
# > Predicted = $731.0, Actual = $1139.0
# > Predicted = $1701.0, Actual = $1451.0
# > Predicted = $1260.0, Actual = $1244.0
# > Predicted = $1481.0, Actual = $1251.0
# > Predicted = $364.0, Actual = $432.0
# > Predicted = $7516.0, Actual = $7322.0
# > Predicted = $843.0, Actual = $880.0
# > Predicted = $1011.0, Actual = $1212.0
# > Predicted = $541.0, Actual = $593.0
# > Predicted = $1150.0, Actual = $1641.0
# > Predicted = $679.0, Actual = $906.0
# > Predicted = $1555.0, Actual = $1647.0
# > Predicted = $1647.0, Actual = $1275.0
# > Predicted = $696.0, Actual = $721.0
# > Predicted = $957.0, Actual = $1176.0
# > Predicted = $361.0, Actual = $509.0
# > Predicted = $1167.0, Actual = $781.0
# > Predicted = $720.0, Actual = $802.0
# > Predicted = $2994.0, Actual = $3695.0
# > Predicted = $896.0, Actual = $887.0
# > Predicted = $1972.0, Actual = $1968.0
# > Predicted = $2137.0, Actual = $2730.0
# > Predicted = $677.0, Actual = $723.0
# > Predicted = $793.0, Actual = $805.0
# > Predicted = $1148.0, Actual = $990.0
# > Predicted = $497.0, Actual = $407.0
# > Predicted = $1627.0, Actual = $1805.0
# > Predicted = $701.0, Actual = $1122.0
# > Predicted = $934.0, Actual = $1345.0
# > Predicted = $3669.0, Actual = $3247.0
# > Predicted = $2377.0, Actual = $2269.0
# > Predicted = $1259.0, Actual = $1232.0
# > Predicted = $1452.0, Actual = $1432.0
# > Predicted = $2000.0, Actual = $1576.0
# > Predicted = $819.0, Actual = $826.0
# > Predicted = $473.0, Actual = $471.0
# > Predicted = $196.0, Actual = $238.0
# > Predicted = $1240.0, Actual = $1586.0
# > Predicted = $1479.0, Actual = $1468.0
# > Predicted = $1106.0, Actual = $1326.0
# > Predicted = $361.0, Actual = $519.0
# > Predicted = $990.0, Actual = $865.0
# > Predicted = $2344.0, Actual = $1544.0
# > Predicted = $2519.0, Actual = $1952.0
# > Predicted = $741.0, Actual = $1172.0
# > Predicted = $1283.0, Actual = $1131.0
# > Predicted = $673.0, Actual = $722.0
# > Predicted = $1574.0, Actual = $1764.0
# > Predicted = $2950.0, Actual = $2745.0
# > Predicted = $1408.0, Actual = $1200.0
# > Predicted = $333.0, Actual = $398.0
# > Predicted = $701.0, Actual = $1078.0
# > Predicted = $3615.0, Actual = $4118.0
# > Predicted = $2579.0, Actual = $2747.0
# > Predicted = $1625.0, Actual = $1735.0
# > Predicted = $1296.0, Actual = $998.0
# > Predicted = $1021.0, Actual = $1350.0
# > Predicted = $667.0, Actual = $1082.0
# > Predicted = $499.0, Actual = $496.0
# > Predicted = $683.0, Actual = $730.0
# > Predicted = $134.0, Actual = $212.0
# > Predicted = $762.0, Actual = $432.0
# > Predicted = $978.0, Actual = $1000.0
# > Predicted = $788.0, Actual = $755.0
# > Predicted = $1684.0, Actual = $1274.0
# > Predicted = $370.0, Actual = $579.0
# > Predicted = $325.0, Actual = $315.0
# > Predicted = $905.0, Actual = $767.0
# > Predicted = $1200.0, Actual = $1041.0
# > Predicted = $756.0, Actual = $766.0
# > Predicted = $2836.0, Actual = $2608.0
# > Predicted = $2195.0, Actual = $2099.0
# > Predicted = $2093.0, Actual = $2064.0
# > Predicted = $1581.0, Actual = $2213.0
# > Predicted = $1165.0, Actual = $887.0
# > Predicted = $303.0, Actual = $224.0
# > Predicted = $2095.0, Actual = $1983.0
# > Predicted = $1129.0, Actual = $1314.0
# > Predicted = $1570.0, Actual = $1538.0
# > Predicted = $559.0, Actual = $574.0
# > Predicted = $495.0, Actual = $459.0
# > Predicted = $844.0, Actual = $910.0
# > Predicted = $879.0, Actual = $1050.0
# > Predicted = $677.0, Actual = $809.0
# > Predicted = $883.0, Actual = $768.0
# > Predicted = $1151.0, Actual = $2043.0
# > Predicted = $955.0, Actual = $954.0
# > Predicted = $343.0, Actual = $121.0
# > Predicted = $1407.0, Actual = $1698.0
# > Predicted = $684.0, Actual = $759.0
# > Predicted = $1628.0, Actual = $1532.0
# > Predicted = $1597.0, Actual = $2751.0
# > Predicted = $2966.0, Actual = $2209.0
# > Predicted = $3172.0, Actual = $2892.0
# > Predicted = $968.0, Actual = $1522.0
# > Predicted = $1042.0, Actual = $1030.0
# > Predicted = $850.0, Actual = $703.0
# > Predicted = $289.0, Actual = $216.0
# > Predicted = $1182.0, Actual = $878.0
# > Predicted = $967.0, Actual = $815.0
# > Predicted = $644.0, Actual = $1159.0
# > Predicted = $2236.0, Actual = $2503.0
# > Predicted = $648.0, Actual = $459.0
# > Predicted = $847.0, Actual = $800.0
# > Predicted = $1684.0, Actual = $1437.0
# > Predicted = $1164.0, Actual = $632.0
# > Predicted = $517.0, Actual = $351.0
# > Predicted = $1900.0, Actual = $2186.0
# > Predicted = $1275.0, Actual = $1033.0
# > Predicted = $1446.0, Actual = $1264.0
# > Predicted = $2046.0, Actual = $2660.0
# > Predicted = $691.0, Actual = $501.0
# > Predicted = $660.0, Actual = $1183.0
# > Predicted = $1788.0, Actual = $2011.0
# > Predicted = $1807.0, Actual = $2605.0
# > Predicted = $5947.0, Actual = $5698.0
# > Predicted = $1445.0, Actual = $1216.0
# > Predicted = $735.0, Actual = $457.0
# > Predicted = $1559.0, Actual = $1566.0
# > Predicted = $2431.0, Actual = $2102.0
# > Predicted = $632.0, Actual = $619.0
# > Predicted = $994.0, Actual = $426.0
# > Predicted = $1580.0, Actual = $1685.0
# > Predicted = $265.0, Actual = $322.0
# > Predicted = $1218.0, Actual = $1291.0
# > Predicted = $661.0, Actual = $438.0
# > Predicted = $653.0, Actual = $750.0
# > Predicted = $1940.0, Actual = $1554.0
# > Predicted = $1235.0, Actual = $1235.0
# > Predicted = $969.0, Actual = $858.0
# > Predicted = $1034.0, Actual = $858.0
# > Predicted = $145.0, Actual = $254.0
# > Predicted = $720.0, Actual = $575.0
# > Predicted = $247.0, Actual = $224.0
# > Predicted = $588.0, Actual = $599.0
# > Predicted = $501.0, Actual = $832.0
# > Predicted = $719.0, Actual = $786.0
# > Predicted = $1097.0, Actual = $1174.0
# > Predicted = $1793.0, Actual = $1738.0
# > Predicted = $309.0, Actual = $447.0
# > Predicted = $824.0, Actual = $992.0
# > Predicted = $1404.0, Actual = $948.0
# > Predicted = $568.0, Actual = $911.0
# > Predicted = $1236.0, Actual = $974.0
# > Predicted = $1305.0, Actual = $1676.0
# > Predicted = $633.0, Actual = $445.0
# > Predicted = $2209.0, Actual = $2321.0
# > Predicted = $233.0, Actual = $312.0
# > Predicted = $761.0, Actual = $766.0
# > Predicted = $1431.0, Actual = $1511.0
# > Predicted = $2515.0, Actual = $2358.0
# > Predicted = $755.0, Actual = $677.0
# > Predicted = $1689.0, Actual = $1473.0
# > Predicted = $551.0, Actual = $586.0
# > Predicted = $1932.0, Actual = $1417.0
# > Predicted = $351.0, Actual = $323.0
# > Predicted = $1031.0, Actual = $948.0
# > Predicted = $394.0, Actual = $526.0
# > Predicted = $2815.0, Actual = $3467.0
# > Predicted = $490.0, Actual = $454.0
# Accuracy: 67.70186335403726
